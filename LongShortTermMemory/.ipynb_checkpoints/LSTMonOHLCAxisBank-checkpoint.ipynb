# %% [markdown]
# # Imports

# %%
import numpy as np

from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error , mean_squared_error

import tensorflow as tf
from tensorflow.keras.layers import LSTM , Dropout , Dense
from tensorflow.keras.models import Sequential

import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/EQ_daily/AXISBANKEQ.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
df.drop(df[df['High']==df['Low']].index , axis=0 , inplace=True)
df.head()
# Out:
#                 Ticker       Date      Time  Open  High   Low  Close  Volume  \
# Date
# 1998-12-02  AXISBANKEQ 1998-12-02  00:00:00  3.36  3.44  3.32   3.39   75000
# 1998-12-03  AXISBANKEQ 1998-12-03  00:00:00  3.89  3.89  3.36   3.40  538000
# 1998-12-04  AXISBANKEQ 1998-12-04  00:00:00  3.37  3.39  3.26   3.31  182000
# 1998-12-07  AXISBANKEQ 1998-12-07  00:00:00  3.31  3.35  3.29   3.33  112500
# 1998-12-08  AXISBANKEQ 1998-12-08  00:00:00  3.27  3.32  3.20   3.25  271000
#
#             OI
# Date
# 1998-12-02    0
# 1998-12-03    0
# 1998-12-04    0
# 1998-12-07    0
# 1998-12-08    0

# %%
df.drop(['Ticker' , 'Date' ,'Time', 'Volume' , 'OI '] , axis=1 , inplace=True)
df = df.loc['2009-01':]
data = df.copy()

# %%
plt.figure(figsize=(30 , 15))
plt.scatter(df.index , df['Close'])
plt.title('Time vs Close Price')
plt.show()

# %%
data.isnull().sum()
# Out:
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
data[data['High'] == data['Low']]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close]
# Index: []

# %%
data[data['Close'] == data['Open']]
# Out:
#               Open    High     Low   Close
# Date
# 2009-07-24  178.79  181.38  176.00  178.79
# 2016-06-17  526.90  533.90  524.70  526.90
# 2016-10-28  486.90  494.00  484.55  486.90
# 2017-12-26  555.00  557.25  550.30  555.00

# %%
df.loc['2009-07']
# Out:
#               Open    High     Low   Close
# Date
# 2009-07-01  167.60  175.98  166.03  173.88
# 2009-07-02  175.00  176.58  167.32  170.74
# 2009-07-03  169.42  175.20  167.48  174.67
# 2009-07-06  176.02  177.00  156.32  158.88
# 2009-07-07  159.60  165.20  159.00  163.35
# 2009-07-08  160.24  163.20  154.31  157.30
# 2009-07-09  155.27  159.40  149.02  152.99
# 2009-07-10  154.00  157.40  145.22  147.65
# 2009-07-13  143.80  154.26  141.42  151.08
# 2009-07-14  155.60  157.00  149.71  152.64
# 2009-07-15  154.40  159.94  152.20  157.74
# 2009-07-16  161.67  164.00  156.80  159.73
# 2009-07-17  161.40  171.50  160.40  170.22
# 2009-07-20  183.76  183.76  163.33  177.27
# 2009-07-21  179.38  179.38  172.01  176.88
# 2009-07-22  183.74  183.74  170.41  172.14
# 2009-07-23  175.00  179.54  174.20  178.79
# 2009-07-24  178.79  181.38  176.00  178.79
# 2009-07-27  180.00  189.86  176.02  187.67
# 2009-07-28  188.20  194.88  183.06  191.32
# 2009-07-29  184.53  189.26  178.47  183.52
# 2009-07-30  183.00  186.80  179.40  184.12
# 2009-07-31  188.00  189.50  181.60  183.43

# %%
# Training and testing data
train_size = int(len(data) *0.80)
train = data[:train_size]
test = data[train_size :]

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_close = scaler.fit_transform(np.array(train['Close']).reshape(-1,1))

# %%
scaled_open = scaler.transform(np.array(train['Open']).reshape(-1,1))
scaled_high = scaler.transform(np.array(train['High']).reshape(-1,1))
scaled_low = scaler.transform(np.array(train['Low']).reshape(-1,1))

# %%
open_list = []
close_list = []
high_list = []
low_list = []
for i in range(len(scaled_open)):
    open_list.append(scaled_open[i])
    high_list.append(scaled_high[i])
    low_list.append(scaled_low[i])
    close_list.append( scaled_close[i])

# %%
open_arr = np.array(open_list).reshape(-1,1)
high_arr = np.array(high_list).reshape(-1,1)
low_arr = np.array(low_list).reshape(-1,1)
close_arr = np.array(close_list).reshape(-1,1)

# %%
scaled_data = pd.DataFrame(open_arr , columns=['Open'])

# %%
scaled_data['High'] = high_arr
scaled_data['Low'] = low_arr
scaled_data['Close'] = close_arr

# %%
scaled_train = np.array(scaled_data)

# %%
X_train = []
y_train = []

for x in range(60,len(scaled_train)-1):
    temp = []
    for i in scaled_train[x-60 :x,]:
        temp.append(i[0] )
        temp.append(i[1])
        temp.append( i[2])
        temp.append(i[3])
        
    X_train.append(temp)
    
    y_train.append(scaled_train[x+1][3])

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
test_scaled_close = scaler.transform(np.array(test['Close']).reshape(-1,1))
test_scaled_open = scaler.transform(np.array(test['Open']).reshape(-1,1))
test_scaled_high = scaler.transform(np.array(test['High']).reshape(-1,1))
test_scaled_low = scaler.transform(np.array(test['Low']).reshape(-1,1))

# %%
open_list = []
close_list = []
high_list = []
low_list = []
for i in range(len(test_scaled_open)):
    open_list.append(test_scaled_open[i])
    high_list.append(test_scaled_high[i])
    low_list.append(test_scaled_low[i])
    close_list.append( test_scaled_close[i])

# %%
open_arr = np.array(open_list).reshape(-1,1)
high_arr = np.array(high_list).reshape(-1,1)
low_arr = np.array(low_list).reshape(-1,1)
close_arr = np.array(close_list).reshape(-1,1)

# %%
scaled_data = pd.DataFrame(open_arr , columns=['Open'])
scaled_data['High'] = high_arr
scaled_data['Low'] = low_arr
scaled_data['Close'] = close_arr

# %%
scaled_test = np.array(scaled_data)

# %%
X_test = []
y_test = []

for x in range(60,len(scaled_test)-1):
    temp = []
    for i in scaled_test[x-60 :x,]:
        temp.append(i[0] )
        temp.append(i[1])
        temp.append( i[2])
        temp.append(i[3])
        
    X_test.append(temp)
    
    y_test.append(scaled_test[x+1][3])

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
lstm = Sequential()
lstm.add(LSTM(250 ,return_sequences=True ,  input_shape=(240,1)))
lstm.add(LSTM(250 , return_sequences = True))
lstm.add(LSTM(250))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error' , optimizer='adam' , metrics=['accuracy','mse'])

# %%
lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 240, 250)          252000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 240, 250)          501000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 250)               501000
# _________________________________________________________________
# dense (Dense)                (None, 1)                 251
# =================================================================
# Total params: 1,254,251
# Trainable params: 1,254,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train = X_train.reshape((-1,240 , 1))
y_train = y_train.reshape(-1,1)
X_test = X_test.reshape((-1,240,1))
y_train = y_train.reshape(-1,1)

# %%
lstm.fit(X_train ,y_train , validation_data=(X_test,y_test) ,epochs=100 , batch_size=64 ,verbose=1 )
# Out:
# Epoch 1/100
# 31/31 [==============================] - 73s 2s/step - loss: 6.5505e-04 - accuracy: 5.0403e-04 - mse: 6.5505e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 2/100
# 31/31 [==============================] - 69s 2s/step - loss: 5.2900e-04 - accuracy: 5.0403e-04 - mse: 5.2900e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 3/100
# 31/31 [==============================] - 71s 2s/step - loss: 5.1750e-04 - accuracy: 5.0403e-04 - mse: 5.1750e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 4/100
# 31/31 [==============================] - 68s 2s/step - loss: 5.1383e-04 - accuracy: 5.0403e-04 - mse: 5.1383e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 5/100
# 31/31 [==============================] - 69s 2s/step - loss: 5.7431e-04 - accuracy: 5.0403e-04 - mse: 5.7431e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 6/100
# 31/31 [==============================] - 68s 2s/step - loss: 5.4193e-04 - accuracy: 5.0403e-04 - mse: 5.4193e-04 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - val_mse: 0.0019
# Epoch 7/100
# 31/31 [==============================] - 71s 2s/step - loss: 5.8344e-04 - accuracy: 5.0403e-04 - mse: 5.8344e-04 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - val_mse: 0.0019
# Epoch 8/100
# 31/31 [==============================] - 72s 2s/step - loss: 5.8714e-04 - accuracy: 5.0403e-04 - mse: 5.8714e-04 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - val_mse: 0.0020
# Epoch 9/100
# 31/31 [==============================] - 74s 2s/step - loss: 5.6849e-04 - accuracy: 5.0403e-04 - mse: 5.6849e-04 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - val_mse: 0.0020
# Epoch 10/100
# 31/31 [==============================] - 74s 2s/step - loss: 5.5251e-04 - accuracy: 5.0403e-04 - mse: 5.5251e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 11/100
# 31/31 [==============================] - 71s 2s/step - loss: 5.9398e-04 - accuracy: 5.0403e-04 - mse: 5.9398e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 12/100
# 31/31 [==============================] - 73s 2s/step - loss: 5.1038e-04 - accuracy: 5.0403e-04 - mse: 5.1038e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 13/100
# 31/31 [==============================] - 71s 2s/step - loss: 5.4099e-04 - accuracy: 5.0403e-04 - mse: 5.4099e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 14/100
# 31/31 [==============================] - 71s 2s/step - loss: 5.6033e-04 - accuracy: 5.0403e-04 - mse: 5.6033e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 15/100
# 31/31 [==============================] - 79s 3s/step - loss: 5.4777e-04 - accuracy: 5.0403e-04 - mse: 5.4777e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 16/100
# 31/31 [==============================] - 84s 3s/step - loss: 5.4469e-04 - accuracy: 5.0403e-04 - mse: 5.4469e-04 - val_loss: 9.5854e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.5854e-04
# Epoch 17/100
# 31/31 [==============================] - 84s 3s/step - loss: 5.2966e-04 - accuracy: 5.0403e-04 - mse: 5.2966e-04 - val_loss: 9.3726e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.3726e-04
# Epoch 18/100
# 31/31 [==============================] - 85s 3s/step - loss: 4.9225e-04 - accuracy: 5.0403e-04 - mse: 4.9225e-04 - val_loss: 9.3326e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.3326e-04
# Epoch 19/100
# 31/31 [==============================] - 74s 2s/step - loss: 5.2478e-04 - accuracy: 5.0403e-04 - mse: 5.2478e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 20/100
# 31/31 [==============================] - 74s 2s/step - loss: 5.2940e-04 - accuracy: 5.0403e-04 - mse: 5.2940e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 21/100
# 31/31 [==============================] - 74s 2s/step - loss: 5.1477e-04 - accuracy: 5.0403e-04 - mse: 5.1477e-04 - val_loss: 9.5616e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.5616e-04
# Epoch 22/100
# 31/31 [==============================] - 76s 2s/step - loss: 5.8971e-04 - accuracy: 5.0403e-04 - mse: 5.8971e-04 - val_loss: 9.2060e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.2060e-04
# Epoch 23/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.8276e-04 - accuracy: 5.0403e-04 - mse: 4.8276e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 24/100
# 31/31 [==============================] - 73s 2s/step - loss: 5.0080e-04 - accuracy: 5.0403e-04 - mse: 5.0080e-04 - val_loss: 9.9037e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.9037e-04
# Epoch 25/100
# 31/31 [==============================] - 74s 2s/step - loss: 4.8717e-04 - accuracy: 5.0403e-04 - mse: 4.8717e-04 - val_loss: 9.1566e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.1566e-04
# Epoch 26/100
# 31/31 [==============================] - 73s 2s/step - loss: 5.6568e-04 - accuracy: 5.0403e-04 - mse: 5.6568e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 27/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.9233e-04 - accuracy: 5.0403e-04 - mse: 4.9233e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 28/100
# 31/31 [==============================] - 70s 2s/step - loss: 5.2427e-04 - accuracy: 5.0403e-04 - mse: 5.2427e-04 - val_loss: 9.2440e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.2440e-04
# Epoch 29/100
# 31/31 [==============================] - 69s 2s/step - loss: 6.7187e-04 - accuracy: 5.0403e-04 - mse: 6.7187e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 30/100
# 31/31 [==============================] - 70s 2s/step - loss: 5.2844e-04 - accuracy: 5.0403e-04 - mse: 5.2844e-04 - val_loss: 8.9687e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.9687e-04
# Epoch 31/100
# 31/31 [==============================] - 73s 2s/step - loss: 6.1355e-04 - accuracy: 5.0403e-04 - mse: 6.1355e-04 - val_loss: 9.4000e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.4000e-04
# Epoch 32/100
# 31/31 [==============================] - 69s 2s/step - loss: 5.3562e-04 - accuracy: 5.0403e-04 - mse: 5.3562e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 33/100
# 31/31 [==============================] - 68s 2s/step - loss: 5.1934e-04 - accuracy: 5.0403e-04 - mse: 5.1934e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 34/100
# 31/31 [==============================] - 69s 2s/step - loss: 4.9503e-04 - accuracy: 5.0403e-04 - mse: 4.9503e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 35/100
# 31/31 [==============================] - 70s 2s/step - loss: 5.3850e-04 - accuracy: 5.0403e-04 - mse: 5.3850e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 36/100
# 31/31 [==============================] - 74s 2s/step - loss: 5.4121e-04 - accuracy: 5.0403e-04 - mse: 5.4121e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 37/100
# 31/31 [==============================] - 84s 3s/step - loss: 4.9038e-04 - accuracy: 5.0403e-04 - mse: 4.9038e-04 - val_loss: 8.3841e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3841e-04
# Epoch 38/100
# 31/31 [==============================] - 77s 2s/step - loss: 5.1198e-04 - accuracy: 5.0403e-04 - mse: 5.1198e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 39/100
# 31/31 [==============================] - 86s 3s/step - loss: 5.1039e-04 - accuracy: 5.0403e-04 - mse: 5.1039e-04 - val_loss: 8.8668e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.8668e-04
# Epoch 40/100
# 31/31 [==============================] - 85s 3s/step - loss: 5.2894e-04 - accuracy: 5.0403e-04 - mse: 5.2894e-04 - val_loss: 8.1836e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.1836e-04
# Epoch 41/100
# 31/31 [==============================] - 84s 3s/step - loss: 5.1139e-04 - accuracy: 5.0403e-04 - mse: 5.1139e-04 - val_loss: 0.0018 - val_accuracy: 0.0000e+00 - val_mse: 0.0018
# Epoch 42/100
# 31/31 [==============================] - 93s 3s/step - loss: 4.8015e-04 - accuracy: 5.0403e-04 - mse: 4.8015e-04 - val_loss: 8.3492e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3492e-04
# Epoch 43/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.6673e-04 - accuracy: 5.0403e-04 - mse: 4.6673e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 44/100
# 31/31 [==============================] - 78s 3s/step - loss: 5.5647e-04 - accuracy: 5.0403e-04 - mse: 5.5647e-04 - val_loss: 0.0052 - val_accuracy: 0.0000e+00 - val_mse: 0.0052
# Epoch 45/100
# 31/31 [==============================] - 76s 2s/step - loss: 5.0860e-04 - accuracy: 5.0403e-04 - mse: 5.0860e-04 - val_loss: 8.0627e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.0627e-04
# Epoch 46/100
# 31/31 [==============================] - 74s 2s/step - loss: 4.7140e-04 - accuracy: 5.0403e-04 - mse: 4.7140e-04 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - val_mse: 0.0017
# Epoch 47/100
# 31/31 [==============================] - 78s 3s/step - loss: 5.3187e-04 - accuracy: 5.0403e-04 - mse: 5.3187e-04 - val_loss: 7.9929e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.9929e-04
# Epoch 48/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.2103e-04 - accuracy: 5.0403e-04 - mse: 4.2103e-04 - val_loss: 7.7459e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.7459e-04
# Epoch 49/100
# 31/31 [==============================] - 79s 3s/step - loss: 4.5133e-04 - accuracy: 5.0403e-04 - mse: 4.5133e-04 - val_loss: 8.3524e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3524e-04
# Epoch 50/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.3540e-04 - accuracy: 5.0403e-04 - mse: 4.3540e-04 - val_loss: 8.4224e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.4224e-04
# Epoch 51/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.3015e-04 - accuracy: 5.0403e-04 - mse: 4.3015e-04 - val_loss: 7.8882e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.8882e-04
# Epoch 52/100
# 31/31 [==============================] - 77s 2s/step - loss: 4.1559e-04 - accuracy: 5.0403e-04 - mse: 4.1559e-04 - val_loss: 8.3766e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3766e-04
# Epoch 53/100
# 31/31 [==============================] - 78s 3s/step - loss: 5.8313e-04 - accuracy: 5.0403e-04 - mse: 5.8313e-04 - val_loss: 8.5911e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.5911e-04
# Epoch 54/100
# 31/31 [==============================] - 78s 3s/step - loss: 4.4325e-04 - accuracy: 5.0403e-04 - mse: 4.4325e-04 - val_loss: 8.2995e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.2995e-04
# Epoch 55/100
# 31/31 [==============================] - 72s 2s/step - loss: 5.2919e-04 - accuracy: 5.0403e-04 - mse: 5.2919e-04 - val_loss: 7.6188e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.6188e-04
# Epoch 56/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.2151e-04 - accuracy: 5.0403e-04 - mse: 4.2151e-04 - val_loss: 7.9392e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.9392e-04
# Epoch 57/100
# 31/31 [==============================] - 71s 2s/step - loss: 5.0574e-04 - accuracy: 5.0403e-04 - mse: 5.0574e-04 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - val_mse: 0.0020
# Epoch 58/100
# 31/31 [==============================] - 71s 2s/step - loss: 4.5306e-04 - accuracy: 5.0403e-04 - mse: 4.5306e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 59/100
# 31/31 [==============================] - 71s 2s/step - loss: 4.9968e-04 - accuracy: 5.0403e-04 - mse: 4.9968e-04 - val_loss: 8.3476e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3476e-04
# Epoch 60/100
# 31/31 [==============================] - 70s 2s/step - loss: 4.2734e-04 - accuracy: 5.0403e-04 - mse: 4.2734e-04 - val_loss: 9.7474e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.7474e-04
# Epoch 61/100
# 31/31 [==============================] - 71s 2s/step - loss: 4.8153e-04 - accuracy: 5.0403e-04 - mse: 4.8153e-04 - val_loss: 8.8548e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.8548e-04
# Epoch 62/100
# 31/31 [==============================] - 71s 2s/step - loss: 4.3319e-04 - accuracy: 5.0403e-04 - mse: 4.3319e-04 - val_loss: 7.2688e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.2688e-04
# Epoch 63/100
# 31/31 [==============================] - 71s 2s/step - loss: 4.1497e-04 - accuracy: 5.0403e-04 - mse: 4.1497e-04 - val_loss: 9.1523e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.1523e-04
# Epoch 64/100
# 31/31 [==============================] - 84s 3s/step - loss: 4.2134e-04 - accuracy: 5.0403e-04 - mse: 4.2134e-04 - val_loss: 8.3220e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3220e-04
# Epoch 65/100
# 31/31 [==============================] - 74s 2s/step - loss: 4.2182e-04 - accuracy: 5.0403e-04 - mse: 4.2182e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 66/100
# 31/31 [==============================] - 75s 2s/step - loss: 4.8100e-04 - accuracy: 5.0403e-04 - mse: 4.8100e-04 - val_loss: 9.3641e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.3641e-04
# Epoch 67/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.0679e-04 - accuracy: 5.0403e-04 - mse: 4.0679e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 68/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.3099e-04 - accuracy: 5.0403e-04 - mse: 4.3099e-04 - val_loss: 7.0213e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.0213e-04
# Epoch 69/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.0182e-04 - accuracy: 5.0403e-04 - mse: 4.0182e-04 - val_loss: 8.2601e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.2601e-04
# Epoch 70/100
# 31/31 [==============================] - 72s 2s/step - loss: 3.8397e-04 - accuracy: 5.0403e-04 - mse: 3.8397e-04 - val_loss: 7.3333e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.3333e-04
# Epoch 71/100
# 31/31 [==============================] - 70s 2s/step - loss: 4.4790e-04 - accuracy: 5.0403e-04 - mse: 4.4790e-04 - val_loss: 9.4030e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.4030e-04
# Epoch 72/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.2452e-04 - accuracy: 5.0403e-04 - mse: 4.2452e-04 - val_loss: 7.4966e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.4966e-04
# Epoch 73/100
# 31/31 [==============================] - 70s 2s/step - loss: 4.0097e-04 - accuracy: 5.0403e-04 - mse: 4.0097e-04 - val_loss: 7.3021e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.3021e-04
# Epoch 74/100
# 31/31 [==============================] - 71s 2s/step - loss: 4.4842e-04 - accuracy: 5.0403e-04 - mse: 4.4842e-04 - val_loss: 7.1514e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.1514e-04
# Epoch 75/100
# 31/31 [==============================] - 71s 2s/step - loss: 4.2138e-04 - accuracy: 5.0403e-04 - mse: 4.2138e-04 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - val_mse: 0.0017
# Epoch 76/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.6204e-04 - accuracy: 5.0403e-04 - mse: 4.6204e-04 - val_loss: 6.8638e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.8638e-04
# Epoch 77/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.1191e-04 - accuracy: 5.0403e-04 - mse: 4.1191e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 78/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.3001e-04 - accuracy: 5.0403e-04 - mse: 4.3001e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 79/100
# 31/31 [==============================] - 73s 2s/step - loss: 3.9673e-04 - accuracy: 5.0403e-04 - mse: 3.9673e-04 - val_loss: 6.8968e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.8968e-04
# Epoch 80/100
# 31/31 [==============================] - 74s 2s/step - loss: 3.9991e-04 - accuracy: 5.0403e-04 - mse: 3.9991e-04 - val_loss: 9.1684e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.1684e-04
# Epoch 81/100
# 31/31 [==============================] - 75s 2s/step - loss: 4.0672e-04 - accuracy: 5.0403e-04 - mse: 4.0672e-04 - val_loss: 6.8537e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.8537e-04
# Epoch 82/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.8822e-04 - accuracy: 5.0403e-04 - mse: 4.8822e-04 - val_loss: 7.1611e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.1611e-04
# Epoch 83/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.7866e-04 - accuracy: 5.0403e-04 - mse: 4.7866e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 84/100
# 31/31 [==============================] - 71s 2s/step - loss: 3.8711e-04 - accuracy: 5.0403e-04 - mse: 3.8711e-04 - val_loss: 6.6841e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.6841e-04
# Epoch 85/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.4038e-04 - accuracy: 5.0403e-04 - mse: 4.4038e-04 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - val_mse: 0.0019
# Epoch 86/100
# 31/31 [==============================] - 71s 2s/step - loss: 4.2434e-04 - accuracy: 5.0403e-04 - mse: 4.2434e-04 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - val_mse: 0.0016
# Epoch 87/100
# 31/31 [==============================] - 73s 2s/step - loss: 3.9242e-04 - accuracy: 5.0403e-04 - mse: 3.9242e-04 - val_loss: 8.6921e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.6921e-04
# Epoch 88/100
# 31/31 [==============================] - 72s 2s/step - loss: 3.8408e-04 - accuracy: 5.0403e-04 - mse: 3.8408e-04 - val_loss: 7.8900e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.8900e-04
# Epoch 89/100
# 31/31 [==============================] - 71s 2s/step - loss: 3.9816e-04 - accuracy: 5.0403e-04 - mse: 3.9816e-04 - val_loss: 6.9733e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.9733e-04
# Epoch 90/100
# 31/31 [==============================] - 73s 2s/step - loss: 3.6992e-04 - accuracy: 5.0403e-04 - mse: 3.6992e-04 - val_loss: 6.8268e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.8268e-04
# Epoch 91/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.7150e-04 - accuracy: 5.0403e-04 - mse: 4.7150e-04 - val_loss: 0.0033 - val_accuracy: 0.0000e+00 - val_mse: 0.0033
# Epoch 92/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.9992e-04 - accuracy: 5.0403e-04 - mse: 4.9992e-04 - val_loss: 6.5559e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.5559e-04
# Epoch 93/100
# 31/31 [==============================] - 76s 2s/step - loss: 3.7733e-04 - accuracy: 5.0403e-04 - mse: 3.7733e-04 - val_loss: 6.4991e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.4991e-04
# Epoch 94/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.0399e-04 - accuracy: 5.0403e-04 - mse: 4.0399e-04 - val_loss: 8.4894e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.4894e-04
# Epoch 95/100
# 31/31 [==============================] - 74s 2s/step - loss: 3.6609e-04 - accuracy: 5.0403e-04 - mse: 3.6609e-04 - val_loss: 6.5783e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.5783e-04
# Epoch 96/100
# 31/31 [==============================] - 72s 2s/step - loss: 3.8134e-04 - accuracy: 5.0403e-04 - mse: 3.8134e-04 - val_loss: 6.5930e-04 - val_accuracy: 0.0000e+00 - val_mse: 6.5930e-04
# Epoch 97/100
# 31/31 [==============================] - 73s 2s/step - loss: 4.0987e-04 - accuracy: 5.0403e-04 - mse: 4.0987e-04 - val_loss: 7.5092e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.5092e-04
# Epoch 98/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.9425e-04 - accuracy: 5.0403e-04 - mse: 4.9425e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 99/100
# 31/31 [==============================] - 72s 2s/step - loss: 4.1980e-04 - accuracy: 5.0403e-04 - mse: 4.1980e-04 - val_loss: 7.4804e-04 - val_accuracy: 0.0000e+00 - val_mse: 7.4804e-04
# Epoch 100/100
# 31/31 [==============================] - 73s 2s/step - loss: 3.6931e-04 - accuracy: 5.0403e-04 - mse: 3.6931e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010

# %%
training_predictions = lstm.predict(X_train)

# %%
print('Mean Squared Error : {}'.format(mean_squared_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,scaler.inverse_transform(training_predictions) )))
print('Mean Absolute Error : {}'.format(mean_absolute_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,scaler.inverse_transform(training_predictions))))
# Out:
# Mean Squared Error : 130.65560377727192
# Mean Absolute Error : 8.307218720528386

# %%
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(training_predictions) , label='Training Fitting')
plt.plot(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,label='Original Values')
plt.legend()
plt.show()

# %%
preds = lstm.predict(X_test)

# %%
print('Mean Squared Error : {}'.format(mean_squared_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,scaler.inverse_transform(preds) )))
print('Mean Absolute Error : {}'.format(mean_absolute_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,scaler.inverse_transform(preds))))
# Out:
# Mean Squared Error : 361.3997812497222
# Mean Absolute Error : 14.414508706238738

# %%
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(preds) , label='Testing Prediction')
plt.plot(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,label='Test Original')
plt.legend()
plt.show()

# %%
lstm.save('./models/AXISBANKEQ.h5')

# %%
scaled_original = scaler.inverse_transform(np.array(y_test).reshape(-1,1))
scaled_lstm = scaler.inverse_transform(preds)

# %%
scaled_original = scaled_original.reshape(1,-1).tolist()
scaled_lstm  = scaled_lstm.reshape(1,-1).tolist()

# %%
index = test[61:].index

# %%
data = {'Original':scaled_original[0] ,
        'Prediction': scaled_lstm[0]}

# %%
pred_df = pd.DataFrame(data=data , index =index)

# %%
diff = pred_df['Original'] - pred_df['Prediction']

# %%
print(diff.max())
print(diff.min())
# Out:
# 70.9691040039063
# -48.50853271484374

# %%
pred_df.to_csv('./outputs/axisbankout.csv')
