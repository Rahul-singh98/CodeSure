# %% [markdown]
# # Imports

# %%
import numpy as np

from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error , mean_squared_error

import tensorflow as tf
from tensorflow.keras.layers import LSTM , Dropout , Dense
from tensorflow.keras.models import Sequential

import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/Equity/NSE50.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
df.drop(df[df['High']==df['Low']].index , axis=0 , inplace=True)
df.head()
# Out:
#            Ticker       Date      Time    Open    High    Low   Close  \
# Date
# 1995-11-03  NSE50 1995-11-03  00:00:00   994.0  1001.0  993.0  1000.0
# 1995-11-06  NSE50 1995-11-06  00:00:00  1002.0  1002.0  989.0   989.0
# 1995-11-07  NSE50 1995-11-07  00:00:00   987.0   987.0  977.0   978.0
# 1995-11-08  NSE50 1995-11-08  00:00:00   976.0   976.0  963.0   964.0
# 1995-11-09  NSE50 1995-11-09  00:00:00   960.0   960.0  952.0   953.0
#
#               Volume  OI
# Date
# 1995-11-03  12938015    0
# 1995-11-06   9711115    0
# 1995-11-07  10985070    0
# 1995-11-08   7272730    0
# 1995-11-09   7680380    0

# %%
df.drop(['Ticker' , 'Date' ,'Time', 'Volume' , 'OI '] , axis=1 , inplace=True)
data = df.copy()

# %%
# Training and testing data
train_size = int(len(data) *0.80)
train = data[:train_size]
test = data[train_size :]

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_close = scaler.fit_transform(np.array(train['Close']).reshape(-1,1))

# %%
scaled_open = scaler.transform(np.array(train['Open']).reshape(-1,1))
scaled_high = scaler.transform(np.array(train['High']).reshape(-1,1))
scaled_low = scaler.transform(np.array(train['Low']).reshape(-1,1))

# %%
open_list = []
close_list = []
high_list = []
low_list = []
for i in range(len(scaled_open)):
    open_list.append(scaled_open[i])
    high_list.append(scaled_high[i])
    low_list.append(scaled_low[i])
    close_list.append( scaled_close[i])

# %%
open_arr = np.array(open_list).reshape(-1,1)
high_arr = np.array(high_list).reshape(-1,1)
low_arr = np.array(low_list).reshape(-1,1)
close_arr = np.array(close_list).reshape(-1,1)

# %%
scaled_data = pd.DataFrame(open_arr , columns=['Open'])

# %%
scaled_data['High'] = high_arr
scaled_data['Low'] = low_arr
scaled_data['Close'] = close_arr

# %%
scaled_train = np.array(scaled_data)

# %%
X_train = []
y_train = []

for x in range(60,len(scaled_train)-1):
    temp = []
    for i in scaled_train[x-60 :x,]:
        temp.append(i[0] )
        temp.append(i[1])
        temp.append( i[2])
        temp.append(i[3])
        
    X_train.append(temp)
    
    y_train.append(scaled_train[x+1][3])

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_train[1] , y_train[0]
# Out:
# (array([0.02605353, 0.02605353, 0.02446973, 0.02446973, 0.02422607,
#         0.02422607, 0.02300776, 0.02312959, 0.02288593, 0.02288593,
#         0.02130213, 0.02142396, 0.02093664, 0.02093664, 0.01996199,
#         0.02008382, 0.01996199, 0.01996199, 0.019231  , 0.0195965 ,
#         0.0195965 , 0.0195965 , 0.01557608, 0.01569791, 0.01569791,
#         0.01569791, 0.01338312, 0.01399228, 0.01374861, 0.01533242,
#         0.01374861, 0.01521058, 0.01557608, 0.01557608, 0.01374861,
#         0.01411411, 0.01350495, 0.01362678, 0.01179932, 0.01350495,
#         0.01313946, 0.01350495, 0.01265214, 0.01277397, 0.01265214,
#         0.01265214, 0.01070284, 0.01082467, 0.0109465 , 0.0109465 ,
#         0.00838806, 0.00924087, 0.00826622, 0.00826622, 0.00656059,
#         0.00753524, 0.00753524, 0.01058101, 0.00753524, 0.01009369,
#         0.01021552, 0.01106833, 0.00863172, 0.00887538, 0.00802256,
#         0.00802256, 0.00643876, 0.00680425, 0.00692609, 0.00692609,
#         0.00424581, 0.00692609, 0.00643876, 0.00924087, 0.00607327,
#         0.00899721, 0.0097282 , 0.01082467, 0.00948453, 0.01033735,
#         0.00997186, 0.01033735, 0.00899721, 0.00924087, 0.00875355,
#         0.0097282 , 0.00802256, 0.00960636, 0.00997186, 0.01106833,
#         0.0097282 , 0.01106833, 0.01143383, 0.01374861, 0.01143383,
#         0.01350495, 0.01362678, 0.01460143, 0.01204298, 0.01204298,
#         0.01155566, 0.01155566, 0.01045918, 0.01082467, 0.01106833,
#         0.01119017, 0.01058101, 0.01106833, 0.011312  , 0.01228664,
#         0.011312  , 0.01228664, 0.01253031, 0.01265214, 0.01167749,
#         0.01167749, 0.01082467, 0.01167749, 0.01058101, 0.01155566,
#         0.01155566, 0.01167749, 0.011312  , 0.01155566, 0.01143383,
#         0.01167749, 0.01119017, 0.01167749, 0.01167749, 0.01204298,
#         0.01167749, 0.01192115, 0.01216481, 0.01374861, 0.01216481,
#         0.01374861, 0.01374861, 0.0144796 , 0.01350495, 0.01374861,
#         0.01362678, 0.01435777, 0.01338312, 0.01423594, 0.01472326,
#         0.01642889, 0.01472326, 0.01630706, 0.01655072, 0.01703805,
#         0.01533242, 0.01545425, 0.01521058, 0.01521058, 0.01435777,
#         0.01472326, 0.01521058, 0.01521058, 0.01435777, 0.01460143,
#         0.0144796 , 0.0144796 , 0.01362678, 0.01362678, 0.01387045,
#         0.01411411, 0.01301763, 0.01313946, 0.01253031, 0.01253031,
#         0.01167749, 0.01240847, 0.01216481, 0.01216481, 0.01143383,
#         0.01179932, 0.01167749, 0.01167749, 0.0097282 , 0.00997186,
#         0.0093627 , 0.01009369, 0.00838806, 0.00985003, 0.00924087,
#         0.00985003, 0.00924087, 0.00924087, 0.00911904, 0.01045918,
#         0.00899721, 0.01033735, 0.01058101, 0.0109465 , 0.01021552,
#         0.01058101, 0.01106833, 0.01106833, 0.01009369, 0.01009369,
#         0.01009369, 0.01009369, 0.00960636, 0.00985003, 0.00948453,
#         0.00948453, 0.00838806, 0.00838806, 0.00790073, 0.00790073,
#         0.00656059, 0.00741341, 0.00716975, 0.00716975, 0.00631693,
#         0.00680425, 0.00692609, 0.00716975, 0.00680425, 0.00680425,
#         0.00704792, 0.00704792, 0.00522045, 0.00546411, 0.00522045,
#         0.00522045, 0.00339299, 0.00375848, 0.00388031, 0.00388031,
#         0.00314933, 0.00327116, 0.0030275 , 0.00534228, 0.0030275 ,
#         0.00522045, 0.00582961, 0.00729158, 0.00582961, 0.00716975]),
#  0.0072915778316541)

# %%
test_scaled_close = scaler.transform(np.array(test['Close']).reshape(-1,1))
test_scaled_open = scaler.transform(np.array(test['Open']).reshape(-1,1))
test_scaled_high = scaler.transform(np.array(test['High']).reshape(-1,1))
test_scaled_low = scaler.transform(np.array(test['Low']).reshape(-1,1))

# %%
open_list = []
close_list = []
high_list = []
low_list = []
for i in range(len(test_scaled_open)):
    open_list.append(test_scaled_open[i])
    high_list.append(test_scaled_high[i])
    low_list.append(test_scaled_low[i])
    close_list.append( test_scaled_close[i])

# %%
open_arr = np.array(open_list).reshape(-1,1)
high_arr = np.array(high_list).reshape(-1,1)
low_arr = np.array(low_list).reshape(-1,1)
close_arr = np.array(close_list).reshape(-1,1)

# %%
scaled_data = pd.DataFrame(open_arr , columns=['Open'])
scaled_data['High'] = high_arr
scaled_data['Low'] = low_arr
scaled_data['Close'] = close_arr

# %%
scaled_test = np.array(scaled_data)

# %%
X_test = []
y_test = []

for x in range(60,len(scaled_test)-1):
    temp = []
    for i in scaled_test[x-60 :x,]:
        temp.append(i[0] )
        temp.append(i[1])
        temp.append( i[2])
        temp.append(i[3])
        
    X_test.append(temp)
    
    y_test.append(scaled_test[x+1][3])

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
lstm = Sequential()
lstm.add(LSTM(250 ,return_sequences=True ,  input_shape=(240,1)))
lstm.add(LSTM(250 , return_sequences = True))
lstm.add(LSTM(250))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error' , optimizer='adam' , metrics=['accuracy','mse'])

# %%
lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 240, 250)          252000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 240, 250)          501000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 250)               501000
# _________________________________________________________________
# dense (Dense)                (None, 1)                 251
# =================================================================
# Total params: 1,254,251
# Trainable params: 1,254,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train = X_train.reshape((-1,240 , 1))
y_train = y_train.reshape(-1,1)
X_test = X_test.reshape((-1,240,1))
y_train = y_train.reshape(-1,1)

# %%
lstm.fit(X_train ,y_train , validation_data=(X_test,y_test) ,epochs=100 , batch_size=64 ,verbose=1 )
# Out:
# Epoch 1/100
# 77/77 [==============================] - 173s 2s/step - loss: 0.0224 - accuracy: 2.9427e-05 - mse: 0.0224 - val_loss: 0.0069 - val_accuracy: 0.0000e+00 - val_mse: 0.0069
# Epoch 2/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.8093e-04 - accuracy: 5.0896e-04 - mse: 1.8093e-04 - val_loss: 0.0021 - val_accuracy: 0.0000e+00 - val_mse: 0.0021
# Epoch 3/100
# 77/77 [==============================] - 169s 2s/step - loss: 1.7530e-04 - accuracy: 1.2956e-04 - mse: 1.7530e-04 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - val_mse: 0.0019
# Epoch 4/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.7262e-04 - accuracy: 0.0011 - mse: 1.7262e-04 - val_loss: 0.0018 - val_accuracy: 0.0000e+00 - val_mse: 0.0018
# Epoch 5/100
# 77/77 [==============================] - 172s 2s/step - loss: 1.7351e-04 - accuracy: 3.4728e-05 - mse: 1.7351e-04 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - val_mse: 0.0022
# Epoch 6/100
# 77/77 [==============================] - 174s 2s/step - loss: 1.9403e-04 - accuracy: 3.4878e-04 - mse: 1.9403e-04 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - val_mse: 0.0016
# Epoch 7/100
# 77/77 [==============================] - 201s 3s/step - loss: 1.6559e-04 - accuracy: 0.0017 - mse: 1.6559e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 8/100
# 77/77 [==============================] - 170s 2s/step - loss: 1.9018e-04 - accuracy: 1.7502e-04 - mse: 1.9018e-04 - val_loss: 0.0021 - val_accuracy: 0.0000e+00 - val_mse: 0.0021
# Epoch 9/100
# 77/77 [==============================] - 170s 2s/step - loss: 2.2150e-04 - accuracy: 3.1557e-04 - mse: 2.2150e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 10/100
# 77/77 [==============================] - 172s 2s/step - loss: 2.1138e-04 - accuracy: 1.7847e-04 - mse: 2.1138e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 11/100
# 77/77 [==============================] - 171s 2s/step - loss: 1.9092e-04 - accuracy: 8.5178e-04 - mse: 1.9092e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 12/100
# 77/77 [==============================] - 172s 2s/step - loss: 1.7178e-04 - accuracy: 4.4548e-04 - mse: 1.7178e-04 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - val_mse: 0.0016
# Epoch 13/100
# 77/77 [==============================] - 172s 2s/step - loss: 2.7180e-04 - accuracy: 3.3098e-04 - mse: 2.7180e-04 - val_loss: 0.0018 - val_accuracy: 0.0000e+00 - val_mse: 0.0018
# Epoch 14/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.9123e-04 - accuracy: 8.4821e-04 - mse: 1.9123e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 15/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.6670e-04 - accuracy: 1.1896e-04 - mse: 1.6670e-04 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - val_mse: 0.0017
# Epoch 16/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.7286e-04 - accuracy: 3.7708e-04 - mse: 1.7286e-04 - val_loss: 0.0018 - val_accuracy: 0.0000e+00 - val_mse: 0.0018
# Epoch 17/100
# 77/77 [==============================] - 169s 2s/step - loss: 1.7595e-04 - accuracy: 8.8253e-05 - mse: 1.7595e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 18/100
# 77/77 [==============================] - 188s 2s/step - loss: 1.7259e-04 - accuracy: 4.2097e-04 - mse: 1.7259e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 19/100
# 77/77 [==============================] - 175s 2s/step - loss: 1.8230e-04 - accuracy: 3.1501e-04 - mse: 1.8230e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 20/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.5685e-04 - accuracy: 3.6590e-04 - mse: 1.5685e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 21/100
# 77/77 [==============================] - 178s 2s/step - loss: 1.7252e-04 - accuracy: 6.3832e-05 - mse: 1.7252e-04 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - val_mse: 0.0017
# Epoch 22/100
# 77/77 [==============================] - 174s 2s/step - loss: 1.6788e-04 - accuracy: 5.6271e-04 - mse: 1.6788e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 23/100
# 77/77 [==============================] - 180s 2s/step - loss: 1.7523e-04 - accuracy: 4.4856e-04 - mse: 1.7523e-04 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - val_mse: 0.0013
# Epoch 24/100
# 77/77 [==============================] - 179s 2s/step - loss: 1.7769e-04 - accuracy: 3.8429e-04 - mse: 1.7769e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 25/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.3834e-04 - accuracy: 2.1753e-04 - mse: 1.3834e-04 - val_loss: 0.0024 - val_accuracy: 0.0000e+00 - val_mse: 0.0024
# Epoch 26/100
# 77/77 [==============================] - 177s 2s/step - loss: 2.2985e-04 - accuracy: 1.0642e-04 - mse: 2.2985e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 27/100
# 77/77 [==============================] - 175s 2s/step - loss: 1.7464e-04 - accuracy: 1.9840e-04 - mse: 1.7464e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 28/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.3856e-04 - accuracy: 8.1161e-05 - mse: 1.3856e-04 - val_loss: 0.0018 - val_accuracy: 0.0000e+00 - val_mse: 0.0018
# Epoch 29/100
# 77/77 [==============================] - 174s 2s/step - loss: 1.5708e-04 - accuracy: 5.1825e-04 - mse: 1.5708e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 30/100
# 77/77 [==============================] - 172s 2s/step - loss: 1.5415e-04 - accuracy: 6.2566e-04 - mse: 1.5415e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 31/100
# 77/77 [==============================] - 177s 2s/step - loss: 1.7945e-04 - accuracy: 3.0176e-04 - mse: 1.7945e-04 - val_loss: 0.0021 - val_accuracy: 0.0000e+00 - val_mse: 0.0021
# Epoch 32/100
# 77/77 [==============================] - 179s 2s/step - loss: 1.5113e-04 - accuracy: 2.0412e-04 - mse: 1.5113e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 33/100
# 77/77 [==============================] - 172s 2s/step - loss: 1.6624e-04 - accuracy: 2.1076e-04 - mse: 1.6624e-04 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - val_mse: 0.0016
# Epoch 34/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.9390e-04 - accuracy: 1.1120e-04 - mse: 1.9390e-04 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - val_mse: 0.0013
# Epoch 35/100
# 77/77 [==============================] - 183s 2s/step - loss: 1.3471e-04 - accuracy: 3.4007e-04 - mse: 1.3471e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 36/100
# 77/77 [==============================] - 183s 2s/step - loss: 1.3898e-04 - accuracy: 7.4987e-04 - mse: 1.3898e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 37/100
# 77/77 [==============================] - 183s 2s/step - loss: 1.4025e-04 - accuracy: 0.0012 - mse: 1.4025e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 38/100
# 77/77 [==============================] - 179s 2s/step - loss: 1.9171e-04 - accuracy: 6.7334e-04 - mse: 1.9171e-04 - val_loss: 0.0041 - val_accuracy: 0.0000e+00 - val_mse: 0.0041
# Epoch 39/100
# 77/77 [==============================] - 176s 2s/step - loss: 2.3882e-04 - accuracy: 2.9653e-05 - mse: 2.3882e-04 - val_loss: 0.0026 - val_accuracy: 0.0000e+00 - val_mse: 0.0026
# Epoch 40/100
# 77/77 [==============================] - 174s 2s/step - loss: 1.7934e-04 - accuracy: 2.4921e-04 - mse: 1.7934e-04 - val_loss: 9.0085e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.0085e-04
# Epoch 41/100
# 77/77 [==============================] - 178s 2s/step - loss: 1.4479e-04 - accuracy: 5.9333e-04 - mse: 1.4479e-04 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - val_mse: 0.0016
# Epoch 42/100
# 77/77 [==============================] - 173s 2s/step - loss: 1.3287e-04 - accuracy: 1.2094e-04 - mse: 1.3287e-04 - val_loss: 8.9864e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.9864e-04
# Epoch 43/100
# 77/77 [==============================] - 181s 2s/step - loss: 1.5734e-04 - accuracy: 4.3961e-04 - mse: 1.5734e-04 - val_loss: 8.8142e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.8142e-04
# Epoch 44/100
# 77/77 [==============================] - 172s 2s/step - loss: 1.6590e-04 - accuracy: 3.5740e-04 - mse: 1.6590e-04 - val_loss: 9.1024e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.1024e-04
# Epoch 45/100
# 77/77 [==============================] - 169s 2s/step - loss: 1.4265e-04 - accuracy: 0.0011 - mse: 1.4265e-04 - val_loss: 8.8411e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.8411e-04
# Epoch 46/100
# 77/77 [==============================] - 174s 2s/step - loss: 1.2190e-04 - accuracy: 4.3516e-05 - mse: 1.2190e-04 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - val_mse: 0.0022
# Epoch 47/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.3471e-04 - accuracy: 7.0009e-04 - mse: 1.3471e-04 - val_loss: 8.4914e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.4914e-04
# Epoch 48/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.4016e-04 - accuracy: 9.1869e-05 - mse: 1.4016e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 49/100
# 77/77 [==============================] - 182s 2s/step - loss: 1.2589e-04 - accuracy: 3.0756e-04 - mse: 1.2589e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 50/100
# 77/77 [==============================] - 179s 2s/step - loss: 1.1827e-04 - accuracy: 7.7588e-04 - mse: 1.1827e-04 - val_loss: 9.5070e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.5070e-04
# Epoch 51/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.2730e-04 - accuracy: 2.5903e-04 - mse: 1.2730e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 52/100
# 77/77 [==============================] - 179s 2s/step - loss: 1.3634e-04 - accuracy: 0.0011 - mse: 1.3634e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 53/100
# 77/77 [==============================] - 181s 2s/step - loss: 1.7015e-04 - accuracy: 2.5504e-04 - mse: 1.7015e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 54/100
# 77/77 [==============================] - 181s 2s/step - loss: 2.0741e-04 - accuracy: 5.9470e-04 - mse: 2.0741e-04 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - val_mse: 0.0017
# Epoch 55/100
# 77/77 [==============================] - 178s 2s/step - loss: 1.3351e-04 - accuracy: 4.6122e-04 - mse: 1.3351e-04 - val_loss: 8.9258e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.9258e-04
# Epoch 56/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.7707e-04 - accuracy: 2.5182e-04 - mse: 1.7707e-04 - val_loss: 8.4582e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.4582e-04
# Epoch 57/100
# 77/77 [==============================] - 170s 2s/step - loss: 1.1401e-04 - accuracy: 4.0633e-04 - mse: 1.1401e-04 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - val_mse: 0.0013
# Epoch 58/100
# 77/77 [==============================] - 167s 2s/step - loss: 1.7295e-04 - accuracy: 6.6814e-04 - mse: 1.7295e-04 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - val_mse: 0.0020
# Epoch 59/100
# 77/77 [==============================] - 167s 2s/step - loss: 1.6200e-04 - accuracy: 3.2382e-04 - mse: 1.6200e-04 - val_loss: 8.3391e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3391e-04
# Epoch 60/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.2728e-04 - accuracy: 1.6930e-04 - mse: 1.2728e-04 - val_loss: 8.3708e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3708e-04
# Epoch 61/100
# 77/77 [==============================] - 167s 2s/step - loss: 1.2027e-04 - accuracy: 3.1114e-04 - mse: 1.2027e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
# Epoch 62/100
# 77/77 [==============================] - 167s 2s/step - loss: 1.8559e-04 - accuracy: 4.4019e-04 - mse: 1.8559e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 63/100
# 77/77 [==============================] - 167s 2s/step - loss: 1.0993e-04 - accuracy: 4.4285e-04 - mse: 1.0993e-04 - val_loss: 8.2624e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.2624e-04
# Epoch 64/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.2553e-04 - accuracy: 5.3522e-04 - mse: 1.2553e-04 - val_loss: 8.6769e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.6769e-04
# Epoch 65/100
# 77/77 [==============================] - 167s 2s/step - loss: 1.2621e-04 - accuracy: 2.4349e-04 - mse: 1.2621e-04 - val_loss: 8.2988e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.2988e-04
# Epoch 66/100
# 77/77 [==============================] - 168s 2s/step - loss: 2.1521e-04 - accuracy: 5.0794e-04 - mse: 2.1521e-04 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - val_mse: 0.0020
# Epoch 67/100
# 77/77 [==============================] - 166s 2s/step - loss: 1.8711e-04 - accuracy: 1.7603e-04 - mse: 1.8711e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 68/100
# 77/77 [==============================] - 166s 2s/step - loss: 1.0754e-04 - accuracy: 5.3830e-04 - mse: 1.0754e-04 - val_loss: 8.2983e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.2983e-04
# Epoch 69/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.1146e-04 - accuracy: 4.3368e-04 - mse: 1.1146e-04 - val_loss: 8.9104e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.9104e-04
# Epoch 70/100
# 77/77 [==============================] - 182s 2s/step - loss: 1.0813e-04 - accuracy: 2.2851e-04 - mse: 1.0813e-04 - val_loss: 8.7793e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.7793e-04
# Epoch 71/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.7497e-04 - accuracy: 3.0704e-04 - mse: 1.7497e-04 - val_loss: 9.3033e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.3033e-04
# Epoch 72/100
# 77/77 [==============================] - 181s 2s/step - loss: 1.1702e-04 - accuracy: 6.2663e-04 - mse: 1.1702e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 73/100
# 77/77 [==============================] - 177s 2s/step - loss: 1.6511e-04 - accuracy: 4.0817e-04 - mse: 1.6511e-04 - val_loss: 9.2787e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.2787e-04
# Epoch 74/100
# 77/77 [==============================] - 177s 2s/step - loss: 1.0717e-04 - accuracy: 2.7782e-04 - mse: 1.0717e-04 - val_loss: 8.3333e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3333e-04
# Epoch 75/100
# 77/77 [==============================] - 178s 2s/step - loss: 1.1531e-04 - accuracy: 1.5762e-04 - mse: 1.1531e-04 - val_loss: 8.3120e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3120e-04
# Epoch 76/100
# 77/77 [==============================] - 285s 4s/step - loss: 1.4001e-04 - accuracy: 1.9893e-04 - mse: 1.4001e-04 - val_loss: 8.2689e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.2689e-04
# Epoch 77/100
# 77/77 [==============================] - 271s 4s/step - loss: 1.2659e-04 - accuracy: 1.0973e-04 - mse: 1.2659e-04 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - val_mse: 0.0013
# Epoch 78/100
# 77/77 [==============================] - 270s 4s/step - loss: 1.1200e-04 - accuracy: 5.6225e-05 - mse: 1.1200e-04 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - val_mse: 0.0013
# Epoch 79/100
# 77/77 [==============================] - 273s 4s/step - loss: 1.1642e-04 - accuracy: 1.5324e-04 - mse: 1.1642e-04 - val_loss: 8.9198e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.9198e-04
# Epoch 80/100
# 77/77 [==============================] - 276s 4s/step - loss: 1.0980e-04 - accuracy: 3.0125e-04 - mse: 1.0980e-04 - val_loss: 8.2174e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.2174e-04
# Epoch 81/100
# 77/77 [==============================] - 239s 3s/step - loss: 1.1818e-04 - accuracy: 4.3372e-04 - mse: 1.1818e-04 - val_loss: 8.5410e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.5410e-04
# Epoch 82/100
# 77/77 [==============================] - 176s 2s/step - loss: 1.8947e-04 - accuracy: 3.3098e-04 - mse: 1.8947e-04 - val_loss: 8.9176e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.9176e-04
# Epoch 83/100
# 77/77 [==============================] - 179s 2s/step - loss: 1.1666e-04 - accuracy: 2.5193e-04 - mse: 1.1666e-04 - val_loss: 8.3960e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3960e-04
# Epoch 84/100
# 77/77 [==============================] - 173s 2s/step - loss: 1.0196e-04 - accuracy: 2.4180e-04 - mse: 1.0196e-04 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - val_mse: 0.0014
# Epoch 85/100
# 77/77 [==============================] - 173s 2s/step - loss: 1.2092e-04 - accuracy: 2.6328e-04 - mse: 1.2092e-04 - val_loss: 8.1970e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.1970e-04
# Epoch 86/100
# 77/77 [==============================] - 177s 2s/step - loss: 1.0487e-04 - accuracy: 3.9909e-04 - mse: 1.0487e-04 - val_loss: 8.3029e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.3029e-04
# Epoch 87/100
# 77/77 [==============================] - 193s 3s/step - loss: 1.2297e-04 - accuracy: 3.1817e-04 - mse: 1.2297e-04 - val_loss: 9.2434e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.2434e-04
# Epoch 88/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.1170e-04 - accuracy: 0.0012 - mse: 1.1170e-04 - val_loss: 0.0018 - val_accuracy: 0.0000e+00 - val_mse: 0.0018
# Epoch 89/100
# 77/77 [==============================] - 169s 2s/step - loss: 1.3370e-04 - accuracy: 3.6130e-04 - mse: 1.3370e-04 - val_loss: 8.4911e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.4911e-04
# Epoch 90/100
# 77/77 [==============================] - 169s 2s/step - loss: 1.0391e-04 - accuracy: 4.7853e-04 - mse: 1.0391e-04 - val_loss: 9.2313e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.2313e-04
# Epoch 91/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.1089e-04 - accuracy: 0.0014 - mse: 1.1089e-04 - val_loss: 8.9851e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.9851e-04
# Epoch 92/100
# 77/77 [==============================] - 173s 2s/step - loss: 1.1362e-04 - accuracy: 3.9241e-04 - mse: 1.1362e-04 - val_loss: 0.0044 - val_accuracy: 0.0000e+00 - val_mse: 0.0044
# Epoch 93/100
# 77/77 [==============================] - 184s 2s/step - loss: 1.5784e-04 - accuracy: 3.0643e-04 - mse: 1.5784e-04 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - val_mse: 0.0012
# Epoch 94/100
# 77/77 [==============================] - 188s 2s/step - loss: 1.2476e-04 - accuracy: 4.6538e-04 - mse: 1.2476e-04 - val_loss: 8.7113e-04 - val_accuracy: 0.0000e+00 - val_mse: 8.7113e-04
# Epoch 95/100
# 77/77 [==============================] - 173s 2s/step - loss: 1.0588e-04 - accuracy: 2.0359e-04 - mse: 1.0588e-04 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - val_mse: 0.0011
# Epoch 96/100
# 77/77 [==============================] - 174s 2s/step - loss: 1.1197e-04 - accuracy: 3.7069e-04 - mse: 1.1197e-04 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - val_mse: 0.0015
# Epoch 97/100
# 77/77 [==============================] - 168s 2s/step - loss: 9.8996e-05 - accuracy: 5.7416e-04 - mse: 9.8996e-05 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - val_mse: 0.0013
# Epoch 98/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.0955e-04 - accuracy: 6.6282e-04 - mse: 1.0955e-04 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - val_mse: 0.0013
# Epoch 99/100
# 77/77 [==============================] - 168s 2s/step - loss: 1.1036e-04 - accuracy: 1.2079e-04 - mse: 1.1036e-04 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - val_mse: 0.0010
# Epoch 100/100
# 77/77 [==============================] - 169s 2s/step - loss: 1.1549e-04 - accuracy: 1.4736e-04 - mse: 1.1549e-04 - val_loss: 9.0468e-04 - val_accuracy: 0.0000e+00 - val_mse: 9.0468e-04

# %%
training_predictions = lstm.predict(X_train)

# %%
print('Mean Squared Error : {}'.format(mean_squared_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,scaler.inverse_transform(training_predictions) )))
print('Mean Absolute Error : {}'.format(mean_absolute_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,scaler.inverse_transform(training_predictions))))
# Out:
# Mean Squared Error : 6646.597456749025
# Mean Absolute Error : 55.69503308193353

# %%
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(training_predictions) , label='Training Fitting')
plt.plot(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,label='Original Values')
plt.legend()
plt.show()

# %%
print('Mean Squared Error : {}'.format(mean_squared_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,scaler.inverse_transform(preds) )))
print('Mean Absolute Error : {}'.format(mean_absolute_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,scaler.inverse_transform(preds))))
# Out:
# Mean Squared Error : 60950.679821215825
# Mean Absolute Error : 138.95093271088473

# %%
preds = lstm.predict(X_test)

# %%
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(preds) , label='Testing Prediction')
plt.plot(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,label='Test Original')
plt.legend()
plt.show()

# %%
lstm.save_weights('./models/lstm240.weights')

# %%
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"
print(preds)
# Out:
# [[0.8076508 ]
#  [0.7907229 ]
#  [0.78694546]
#  ...
#  [1.7108295 ]
#  [1.6997089 ]
#  [1.6738743 ]]

# %%
# Out:
# [[0.8076508 ]
#  [0.7907229 ]
#  [0.78694546]
#  ...
#  [1.7108295 ]
#  [1.6997089 ]
#  [1.6738743 ]]
