# %%
import numpy as np

np.random.seed(1337)  # for reproducibility
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics._regression import r2_score, mean_squared_error ,mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

from dbn import SupervisedDBNRegression
import matplotlib.pyplot as plt 
import os
import sys 
import time

# %%
df = pd.read_csv('./data/NSE50.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']

# %%
df = df.loc['2011-1':]

# %%
data = df['Close'].copy()

# %%
# Training and testing data
train_size = int(len(data)*0.80)
train = data[:train_size]
test = data[train_size :]

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_train = scaler.fit_transform(np.array(train).reshape(-1,1))

# %%
backcheck = 60
X_train , y_train = [] , []
for i in range(backcheck , len(scaled_train)):
    X_train.append(scaled_train[i-backcheck : i ,0])
    y_train.append(scaled_train[i,0])

# %%
scaled_test = scaler.transform(np.array(test).reshape(-1,1))

# %%
backcheck = 60
X_test , y_test = [] , []
for i in range(backcheck , len(scaled_test)):
    X_test.append(scaled_test[i-backcheck : i,0])
    y_test.append(scaled_test[i ,0])
    
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
regressor = SupervisedDBNRegression(hidden_layers_structure=[100],
                                    learning_rate_rbm=0.0001,
                                    learning_rate=0.0001,
                                    n_epochs_rbm=100,
                                    n_iter_backprop=150,
                                    batch_size=32,
                                    activation_function='relu')

# %%
regressor.fit(X_train , y_train)
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 12.916194
# >> Epoch 2 finished 	RBM Reconstruction error 12.705711
# >> Epoch 3 finished 	RBM Reconstruction error 12.477890
# >> Epoch 4 finished 	RBM Reconstruction error 12.230222
# >> Epoch 5 finished 	RBM Reconstruction error 11.959364
# >> Epoch 6 finished 	RBM Reconstruction error 11.661780
# >> Epoch 7 finished 	RBM Reconstruction error 11.332860
# >> Epoch 8 finished 	RBM Reconstruction error 10.968816
# >> Epoch 9 finished 	RBM Reconstruction error 10.564387
# >> Epoch 10 finished 	RBM Reconstruction error 10.115144
# >> Epoch 11 finished 	RBM Reconstruction error 9.616935
# >> Epoch 12 finished 	RBM Reconstruction error 9.066775
# >> Epoch 13 finished 	RBM Reconstruction error 8.461802
# >> Epoch 14 finished 	RBM Reconstruction error 7.802698
# >> Epoch 15 finished 	RBM Reconstruction error 7.091746
# >> Epoch 16 finished 	RBM Reconstruction error 6.337052
# >> Epoch 17 finished 	RBM Reconstruction error 5.552127
# >> Epoch 18 finished 	RBM Reconstruction error 4.755661
# >> Epoch 19 finished 	RBM Reconstruction error 3.968997
# >> Epoch 20 finished 	RBM Reconstruction error 3.217600
# >> Epoch 21 finished 	RBM Reconstruction error 2.532079
# >> Epoch 22 finished 	RBM Reconstruction error 1.930225
# >> Epoch 23 finished 	RBM Reconstruction error 1.423975
# >> Epoch 24 finished 	RBM Reconstruction error 1.020019
# >> Epoch 25 finished 	RBM Reconstruction error 0.717758
# >> Epoch 26 finished 	RBM Reconstruction error 0.502165
# >> Epoch 27 finished 	RBM Reconstruction error 0.361808
# >> Epoch 28 finished 	RBM Reconstruction error 0.275192
# >> Epoch 29 finished 	RBM Reconstruction error 0.226905
# >> Epoch 30 finished 	RBM Reconstruction error 0.204685
# >> Epoch 31 finished 	RBM Reconstruction error 0.198249
# >> Epoch 32 finished 	RBM Reconstruction error 0.201311
# >> Epoch 33 finished 	RBM Reconstruction error 0.209337
# >> Epoch 34 finished 	RBM Reconstruction error 0.219611
# >> Epoch 35 finished 	RBM Reconstruction error 0.228685
# >> Epoch 36 finished 	RBM Reconstruction error 0.238401
# >> Epoch 37 finished 	RBM Reconstruction error 0.243281
# >> Epoch 38 finished 	RBM Reconstruction error 0.250188
# >> Epoch 39 finished 	RBM Reconstruction error 0.253741
# >> Epoch 40 finished 	RBM Reconstruction error 0.257114
# >> Epoch 41 finished 	RBM Reconstruction error 0.263102
# >> Epoch 42 finished 	RBM Reconstruction error 0.269348
# >> Epoch 43 finished 	RBM Reconstruction error 0.274344
# >> Epoch 44 finished 	RBM Reconstruction error 0.275154
# >> Epoch 45 finished 	RBM Reconstruction error 0.276085
# >> Epoch 46 finished 	RBM Reconstruction error 0.278463
# >> Epoch 47 finished 	RBM Reconstruction error 0.276689
# >> Epoch 48 finished 	RBM Reconstruction error 0.277837
# >> Epoch 49 finished 	RBM Reconstruction error 0.278526
# >> Epoch 50 finished 	RBM Reconstruction error 0.279698
# >> Epoch 51 finished 	RBM Reconstruction error 0.278304
# >> Epoch 52 finished 	RBM Reconstruction error 0.277010
# >> Epoch 53 finished 	RBM Reconstruction error 0.276986
# >> Epoch 54 finished 	RBM Reconstruction error 0.275019
# >> Epoch 55 finished 	RBM Reconstruction error 0.273687
# >> Epoch 56 finished 	RBM Reconstruction error 0.271201
# >> Epoch 57 finished 	RBM Reconstruction error 0.273255
# >> Epoch 58 finished 	RBM Reconstruction error 0.274273
# >> Epoch 59 finished 	RBM Reconstruction error 0.276197
# >> Epoch 60 finished 	RBM Reconstruction error 0.277139
# >> Epoch 61 finished 	RBM Reconstruction error 0.275858
# >> Epoch 62 finished 	RBM Reconstruction error 0.273699
# >> Epoch 63 finished 	RBM Reconstruction error 0.273460
# >> Epoch 64 finished 	RBM Reconstruction error 0.273565
# >> Epoch 65 finished 	RBM Reconstruction error 0.274277
# >> Epoch 66 finished 	RBM Reconstruction error 0.273047
# >> Epoch 67 finished 	RBM Reconstruction error 0.271728
# >> Epoch 68 finished 	RBM Reconstruction error 0.271670
# >> Epoch 69 finished 	RBM Reconstruction error 0.268142
# >> Epoch 70 finished 	RBM Reconstruction error 0.269913
# >> Epoch 71 finished 	RBM Reconstruction error 0.272111
# >> Epoch 72 finished 	RBM Reconstruction error 0.270379
# >> Epoch 73 finished 	RBM Reconstruction error 0.270410
# >> Epoch 74 finished 	RBM Reconstruction error 0.271638
# >> Epoch 75 finished 	RBM Reconstruction error 0.270285
# >> Epoch 76 finished 	RBM Reconstruction error 0.272058
# >> Epoch 77 finished 	RBM Reconstruction error 0.271880
# >> Epoch 78 finished 	RBM Reconstruction error 0.270316
# >> Epoch 79 finished 	RBM Reconstruction error 0.269539
# >> Epoch 80 finished 	RBM Reconstruction error 0.268022
# >> Epoch 81 finished 	RBM Reconstruction error 0.266982
# >> Epoch 82 finished 	RBM Reconstruction error 0.265279
# >> Epoch 83 finished 	RBM Reconstruction error 0.264660
# >> Epoch 84 finished 	RBM Reconstruction error 0.267073
# >> Epoch 85 finished 	RBM Reconstruction error 0.269856
# >> Epoch 86 finished 	RBM Reconstruction error 0.266002
# >> Epoch 87 finished 	RBM Reconstruction error 0.264117
# >> Epoch 88 finished 	RBM Reconstruction error 0.266733
# >> Epoch 89 finished 	RBM Reconstruction error 0.266751
# >> Epoch 90 finished 	RBM Reconstruction error 0.266991
# >> Epoch 91 finished 	RBM Reconstruction error 0.269369
# >> Epoch 92 finished 	RBM Reconstruction error 0.269432
# >> Epoch 93 finished 	RBM Reconstruction error 0.268321
# >> Epoch 94 finished 	RBM Reconstruction error 0.265489
# >> Epoch 95 finished 	RBM Reconstruction error 0.267438
# >> Epoch 96 finished 	RBM Reconstruction error 0.267068
# >> Epoch 97 finished 	RBM Reconstruction error 0.265581
# >> Epoch 98 finished 	RBM Reconstruction error 0.266112
# >> Epoch 99 finished 	RBM Reconstruction error 0.266244
# >> Epoch 100 finished 	RBM Reconstruction error 0.263254
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 0.872654
# >> Epoch 2 finished 	ANN training loss 0.664770
# >> Epoch 3 finished 	ANN training loss 0.507066
# >> Epoch 4 finished 	ANN training loss 0.387112
# >> Epoch 5 finished 	ANN training loss 0.295753
# >> Epoch 6 finished 	ANN training loss 0.226081
# >> Epoch 7 finished 	ANN training loss 0.172918
# >> Epoch 8 finished 	ANN training loss 0.132313
# >> Epoch 9 finished 	ANN training loss 0.101275
# >> Epoch 10 finished 	ANN training loss 0.077575
# >> Epoch 11 finished 	ANN training loss 0.059514
# >> Epoch 12 finished 	ANN training loss 0.045761
# >> Epoch 13 finished 	ANN training loss 0.035289
# >> Epoch 14 finished 	ANN training loss 0.027317
# >> Epoch 15 finished 	ANN training loss 0.021251
# >> Epoch 16 finished 	ANN training loss 0.016636
# >> Epoch 17 finished 	ANN training loss 0.013125
# >> Epoch 18 finished 	ANN training loss 0.010456
# >> Epoch 19 finished 	ANN training loss 0.008424
# >> Epoch 20 finished 	ANN training loss 0.006881
# >> Epoch 21 finished 	ANN training loss 0.005708
# >> Epoch 22 finished 	ANN training loss 0.004815
# >> Epoch 23 finished 	ANN training loss 0.004137
# >> Epoch 24 finished 	ANN training loss 0.003622
# >> Epoch 25 finished 	ANN training loss 0.003230
# >> Epoch 26 finished 	ANN training loss 0.002932
# >> Epoch 27 finished 	ANN training loss 0.002704
# >> Epoch 28 finished 	ANN training loss 0.002532
# >> Epoch 29 finished 	ANN training loss 0.002400
# >> Epoch 30 finished 	ANN training loss 0.002299
# >> Epoch 31 finished 	ANN training loss 0.002222
# >> Epoch 32 finished 	ANN training loss 0.002163
# >> Epoch 33 finished 	ANN training loss 0.002118
# >> Epoch 34 finished 	ANN training loss 0.002084
# >> Epoch 35 finished 	ANN training loss 0.002057
# >> Epoch 36 finished 	ANN training loss 0.002036
# >> Epoch 37 finished 	ANN training loss 0.002020
# >> Epoch 38 finished 	ANN training loss 0.002007
# >> Epoch 39 finished 	ANN training loss 0.001997
# >> Epoch 40 finished 	ANN training loss 0.001989
# >> Epoch 41 finished 	ANN training loss 0.001982
# >> Epoch 42 finished 	ANN training loss 0.001977
# >> Epoch 43 finished 	ANN training loss 0.001972
# >> Epoch 44 finished 	ANN training loss 0.001968
# >> Epoch 45 finished 	ANN training loss 0.001965
# >> Epoch 46 finished 	ANN training loss 0.001962
# >> Epoch 47 finished 	ANN training loss 0.001959
# >> Epoch 48 finished 	ANN training loss 0.001957
# >> Epoch 49 finished 	ANN training loss 0.001955
# >> Epoch 50 finished 	ANN training loss 0.001952
# >> Epoch 51 finished 	ANN training loss 0.001950
# >> Epoch 52 finished 	ANN training loss 0.001949
# >> Epoch 53 finished 	ANN training loss 0.001947
# >> Epoch 54 finished 	ANN training loss 0.001945
# >> Epoch 55 finished 	ANN training loss 0.001943
# >> Epoch 56 finished 	ANN training loss 0.001941
# >> Epoch 57 finished 	ANN training loss 0.001940
# >> Epoch 58 finished 	ANN training loss 0.001938
# >> Epoch 59 finished 	ANN training loss 0.001936
# >> Epoch 60 finished 	ANN training loss 0.001935
# >> Epoch 61 finished 	ANN training loss 0.001933
# >> Epoch 62 finished 	ANN training loss 0.001932
# >> Epoch 63 finished 	ANN training loss 0.001930
# >> Epoch 64 finished 	ANN training loss 0.001928
# >> Epoch 65 finished 	ANN training loss 0.001927
# >> Epoch 66 finished 	ANN training loss 0.001925
# >> Epoch 67 finished 	ANN training loss 0.001924
# >> Epoch 68 finished 	ANN training loss 0.001922
# >> Epoch 69 finished 	ANN training loss 0.001921
# >> Epoch 70 finished 	ANN training loss 0.001919
# >> Epoch 71 finished 	ANN training loss 0.001918
# >> Epoch 72 finished 	ANN training loss 0.001916
# >> Epoch 73 finished 	ANN training loss 0.001915
# >> Epoch 74 finished 	ANN training loss 0.001913
# >> Epoch 75 finished 	ANN training loss 0.001912
# >> Epoch 76 finished 	ANN training loss 0.001910
# >> Epoch 77 finished 	ANN training loss 0.001909
# >> Epoch 78 finished 	ANN training loss 0.001908
# >> Epoch 79 finished 	ANN training loss 0.001906
# >> Epoch 80 finished 	ANN training loss 0.001905
# >> Epoch 81 finished 	ANN training loss 0.001903
# >> Epoch 82 finished 	ANN training loss 0.001902
# >> Epoch 83 finished 	ANN training loss 0.001901
# >> Epoch 84 finished 	ANN training loss 0.001899
# >> Epoch 85 finished 	ANN training loss 0.001898
# >> Epoch 86 finished 	ANN training loss 0.001896
# >> Epoch 87 finished 	ANN training loss 0.001895
# >> Epoch 88 finished 	ANN training loss 0.001894
# >> Epoch 89 finished 	ANN training loss 0.001892
# >> Epoch 90 finished 	ANN training loss 0.001891
# >> Epoch 91 finished 	ANN training loss 0.001890
# >> Epoch 92 finished 	ANN training loss 0.001889
# >> Epoch 93 finished 	ANN training loss 0.001887
# >> Epoch 94 finished 	ANN training loss 0.001886
# >> Epoch 95 finished 	ANN training loss 0.001885
# >> Epoch 96 finished 	ANN training loss 0.001883
# >> Epoch 97 finished 	ANN training loss 0.001882
# >> Epoch 98 finished 	ANN training loss 0.001881
# >> Epoch 99 finished 	ANN training loss 0.001880
# >> Epoch 100 finished 	ANN training loss 0.001878
# >> Epoch 101 finished 	ANN training loss 0.001877
# >> Epoch 102 finished 	ANN training loss 0.001876
# >> Epoch 103 finished 	ANN training loss 0.001875
# >> Epoch 104 finished 	ANN training loss 0.001873
# >> Epoch 105 finished 	ANN training loss 0.001872
# >> Epoch 106 finished 	ANN training loss 0.001871
# >> Epoch 107 finished 	ANN training loss 0.001870
# >> Epoch 108 finished 	ANN training loss 0.001869
# >> Epoch 109 finished 	ANN training loss 0.001867
# >> Epoch 110 finished 	ANN training loss 0.001866
# >> Epoch 111 finished 	ANN training loss 0.001865
# >> Epoch 112 finished 	ANN training loss 0.001864
# >> Epoch 113 finished 	ANN training loss 0.001863
# >> Epoch 114 finished 	ANN training loss 0.001861
# >> Epoch 115 finished 	ANN training loss 0.001860
# >> Epoch 116 finished 	ANN training loss 0.001859
# >> Epoch 117 finished 	ANN training loss 0.001858
# >> Epoch 118 finished 	ANN training loss 0.001857
# >> Epoch 119 finished 	ANN training loss 0.001856
# >> Epoch 120 finished 	ANN training loss 0.001855
# >> Epoch 121 finished 	ANN training loss 0.001853
# >> Epoch 122 finished 	ANN training loss 0.001852
# >> Epoch 123 finished 	ANN training loss 0.001851
# >> Epoch 124 finished 	ANN training loss 0.001850
# >> Epoch 125 finished 	ANN training loss 0.001849
# >> Epoch 126 finished 	ANN training loss 0.001848
# >> Epoch 127 finished 	ANN training loss 0.001847
# >> Epoch 128 finished 	ANN training loss 0.001846
# >> Epoch 129 finished 	ANN training loss 0.001845
# >> Epoch 130 finished 	ANN training loss 0.001844
# >> Epoch 131 finished 	ANN training loss 0.001843
# >> Epoch 132 finished 	ANN training loss 0.001842
# >> Epoch 133 finished 	ANN training loss 0.001841
# >> Epoch 134 finished 	ANN training loss 0.001839
# >> Epoch 135 finished 	ANN training loss 0.001838
# >> Epoch 136 finished 	ANN training loss 0.001837
# >> Epoch 137 finished 	ANN training loss 0.001836
# >> Epoch 138 finished 	ANN training loss 0.001835
# >> Epoch 139 finished 	ANN training loss 0.001834
# >> Epoch 140 finished 	ANN training loss 0.001833
# >> Epoch 141 finished 	ANN training loss 0.001832
# >> Epoch 142 finished 	ANN training loss 0.001831
# >> Epoch 143 finished 	ANN training loss 0.001830
# >> Epoch 144 finished 	ANN training loss 0.001829
# >> Epoch 145 finished 	ANN training loss 0.001828
# >> Epoch 146 finished 	ANN training loss 0.001827
# >> Epoch 147 finished 	ANN training loss 0.001826
# >> Epoch 148 finished 	ANN training loss 0.001825
# >> Epoch 149 finished 	ANN training loss 0.001824
# >> Epoch 150 finished 	ANN training loss 0.001823
# [END] Fine tuning step
# SupervisedDBNRegression()

# %%
preds = regressor.predict(X_test)

# %%
len(preds)
# Out:
# 428

# %%
plt.figure(figsize=(20,8))
plt.plot(scaler.inverse_transform(preds) , label='Predictions')
plt.plot(scaler.inverse_transform(np.array(y_test).reshape(-1,1)), label = 'Original Values')
plt.legend()
plt.title('Acutal v/s Predicted')
plt.xlabel('Change in Time')
plt.ylabel('Change in Price')
plt.show()

# %%
regressor.save('./models/NSE501For10years.pkl')

# %%
t = scaler.inverse_transform(np.array(y_test).reshape(-1,1))
p =  scaler.inverse_transform(preds)

# %%
r2_score(t,p)
# Out:
# 0.5530770530723131

# %%
mean_squared_error(t , p)
# Out:
# 1082782.5249073217

# %%
mean_absolute_error(t  ,p)
# Out:
# 789.7299307724234
