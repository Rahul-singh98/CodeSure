# %%
import pandas as pd

# %%
df = pd.read_csv("./nse5paisaScriptMaster.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Exch ExchType  Scripcode  \
# 0           0    N        D      49343
# 1           1    N        D      49344
# 2           2    N        D      49345
# 3           3    N        D      49346
# 4           4    N        D      49347
#
#                                                 Name Series  \
# 0  NIFTY 31 Mar 2022 CE 18000.00                 ...     XX
# 1  NIFTY 31 Mar 2022 PE 18000.00                 ...     XX
# 2  BANKNIFTY 30 Sep 2021 CE 36800.00             ...     XX
# 3  BANKNIFTY 30 Sep 2021 PE 36800.00             ...     XX
# 4  BANKNIFTY 30 Sep 2021 CE 36900.00             ...     XX
#
#                 Expiry CpType  StrikeRate WireCat       ISIN  \
# 0  2022-03-31 14:30:00     CE     18000.0              NIFTY
# 1  2022-03-31 14:30:00     PE     18000.0              NIFTY
# 2  2021-09-30 14:30:00     CE     36800.0          BANKNIFTY
# 3  2021-09-30 14:30:00     PE     36800.0          BANKNIFTY
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Exch', 'ExchType', 'Scripcode', 'Name', 'Series',
#        'Expiry', 'CpType', 'StrikeRate', 'WireCat', 'ISIN', 'FullName'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis=1,inplace=True)

# %%
df.head()
# Out:
#   Exch ExchType  Scripcode                                               Name  \
# 0    N        D      49343  NIFTY 31 Mar 2022 CE 18000.00                 ...
# 1    N        D      49344  NIFTY 31 Mar 2022 PE 18000.00                 ...
# 2    N        D      49345  BANKNIFTY 30 Sep 2021 CE 36800.00             ...
# 3    N        D      49346  BANKNIFTY 30 Sep 2021 PE 36800.00             ...
# 4    N        D      49347  BANKNIFTY 30 Sep 2021 CE 36900.00             ...
#
#   Series               Expiry CpType  StrikeRate WireCat       ISIN  \
# 0     XX  2022-03-31 14:30:00     CE     18000.0              NIFTY
# 1     XX  2022-03-31 14:30:00     PE     18000.0              NIFTY
# 2     XX  2021-09-30 14:30:00     CE     36800.0          BANKNIFTY
# 3     XX  2021-09-30 14:30:00     PE     36800.0          BANKNIFTY
# 4     XX  2021-09-30 14:30:00     CE     36900.0          BANKNIFTY
#
#                             FullName
# 0      NIFTY 31 Mar 2022 CE 18000.00
# ...
