# %%
import pandas as pd

# %%
df = pd.read_csv("./nse5paisaScriptMaster.csv")

# %%
df.head()
# Out:
#   Exch ExchType  Scripcode                                               Name  \
# 0    N        D      49343  NIFTY 31 Mar 2022 CE 18000.00                 ...
# 1    N        D      49344  NIFTY 31 Mar 2022 PE 18000.00                 ...
# 2    N        D      49345  BANKNIFTY 30 Sep 2021 CE 36800.00             ...
# 3    N        D      49346  BANKNIFTY 30 Sep 2021 PE 36800.00             ...
# 4    N        D      49347  BANKNIFTY 30 Sep 2021 CE 36900.00             ...
#
#   Series               Expiry CpType  StrikeRate WireCat       ISIN  \
# 0     XX  2022-03-31 14:30:00     CE     18000.0              NIFTY
# 1     XX  2022-03-31 14:30:00     PE     18000.0              NIFTY
# 2     XX  2021-09-30 14:30:00     CE     36800.0          BANKNIFTY
# 3     XX  2021-09-30 14:30:00     PE     36800.0          BANKNIFTY
# 4     XX  2021-09-30 14:30:00     CE     36900.0          BANKNIFTY
#
#                             FullName
# 0      NIFTY 31 Mar 2022 CE 18000.00
# ...

# %%
df.columns
# Out:
# Index(['Exch', 'ExchType', 'Scripcode', 'Name', 'Series', 'Expiry', 'CpType',
#        'StrikeRate', 'WireCat', 'ISIN', 'FullName'],
#       dtype='object')

# %%
df1=df[(df["Exch"]=="N") & (df["Series"]=="EQ")].copy()

# %%
df1
# Out:
#       Exch ExchType  Scripcode  \
# 529      N        C          4
# 531      N        C          7
# 533      N        C         10
# 536      N        C         13
# 538      N        C         17
# ...    ...      ...        ...
# 86526    N        C      31258
# 86527    N        C      31409
# 86528    N        C      31415
# 86530    N        C      31468
# 86531    N        C      31475
#
#                                                     Name Series  \
# 529    21STCENMGM                                    ...     EQ
# 531    AARTIIND                                      ...     EQ
# 533    ABAN                                          ...     EQ
# 536    ABB                                           ...     EQ
# 538    SCAPDVR                                       ...     EQ
# ...                                                  ...    ...
# 86526  NDL                                           ...     EQ
# 86527  MTEDUCARE                                     ...     EQ
# ...

# %%
df1["Name"] = df1["Name"].str.strip()

# %%
df1[df1["Name"]== "NIFTY"]
# Out:
#      Exch ExchType  Scripcode   Name Series               Expiry CpType  \
# 3760    N        C  999920000  NIFTY     EQ  1980-01-01 00:00:00     EQ
#
#       StrikeRate WireCat ISIN  \
# 3760         0.0       Z  NaN
#
#                                                FullName
# 3760  NIFTY                                         ...

# %%
df1[df1["Name"]== "NIFTY"]['FullName']
# Out:
# 3760    NIFTY                                         ...
# Name: FullName, dtype: object

# %%
df1[df1["Name"]== "BANKNIFTY"]
# Out:
#      Exch ExchType  Scripcode       Name Series               Expiry CpType  \
# 3765    N        C  999920005  BANKNIFTY     EQ  1980-01-01 00:00:00     EQ
#
#       StrikeRate WireCat ISIN  \
# 3765         0.0       Z  NaN
#
#                                                FullName
# 3765  BANKNIFTY                                     ...

# %%
locals().get("asin" , None)

# %%
x = 10
