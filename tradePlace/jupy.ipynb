# %%
emptyVars = []

# %%
for i in range(10):
    vars = {}
    vars.update({"new":[]})
    vars.update({"old":[]})

    vars['new'].append(1)
    vars['new'].append(2)
    print(vars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_23007/3634229010.py in <module>
#       4     vars.update({"old":[None]})
#       5
# ----> 6     print(vars['new'][0].append(1))
#
# AttributeError: 'NoneType' object has no attribute 'append'
