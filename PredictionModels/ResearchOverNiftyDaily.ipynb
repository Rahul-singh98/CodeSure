# %% [markdown]
# # Imports

# %%
import numpy as np

np.random.seed(1337)  # for reproducibility
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics._regression import r2_score, mean_squared_error ,mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

from dbn import SupervisedDBNRegression
import matplotlib.pyplot as plt 
import os
import sys 
import time

# %%
df = pd.read_csv('../../data/Equity/NSE50.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']

# %%
df.drop(df[df['High']==df['Low']].index , axis=0 , inplace=True)

# %%
data = df['Close'].copy()

# %%
# Training and testing data
train_size = int(len(data) * 0.80)
train = data[:train_size]
test = data[train_size :]

# %% [markdown]
# ## Scaling training and testing data

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_train = scaler.fit_transform(np.array(train).reshape(-1,1))

# %%
backcheck = 60
X_train , y_train = [] , []
for i in range(backcheck , len(scaled_train)):
    X_train.append(scaled_train[i-backcheck : i ,0])
    y_train.append(scaled_train[i,0])

# %%
scaled_test = scaler.transform(np.array(test).reshape(-1,1))

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (4918, 60)
# (4918,)

# %%
regressor = SupervisedDBNRegression(hidden_layers_structure=[100],
                                    learning_rate_rbm=0.001,
                                    learning_rate=0.001,
                                    n_epochs_rbm=60,
                                    n_iter_backprop=100,
                                    batch_size=32,
                                    activation_function='relu')

# %%
regressor = SupervisedDBNRegression.load('./models/NSE501.pkl')

# %%
regressor.fit(X_train , y_train)
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 2.170569
# >> Epoch 2 finished 	RBM Reconstruction error 0.318780
# >> Epoch 3 finished 	RBM Reconstruction error 0.318929
# >> Epoch 4 finished 	RBM Reconstruction error 0.349805
# >> Epoch 5 finished 	RBM Reconstruction error 0.307079
# >> Epoch 6 finished 	RBM Reconstruction error 0.381365
# >> Epoch 7 finished 	RBM Reconstruction error 0.361000
# >> Epoch 8 finished 	RBM Reconstruction error 0.372109
# >> Epoch 9 finished 	RBM Reconstruction error 0.385718
# >> Epoch 10 finished 	RBM Reconstruction error 0.417606
# >> Epoch 11 finished 	RBM Reconstruction error 0.385918
# >> Epoch 12 finished 	RBM Reconstruction error 0.418794
# >> Epoch 13 finished 	RBM Reconstruction error 0.409947
# >> Epoch 14 finished 	RBM Reconstruction error 0.424065
# >> Epoch 15 finished 	RBM Reconstruction error 0.457718
# >> Epoch 16 finished 	RBM Reconstruction error 0.463594
# >> Epoch 17 finished 	RBM Reconstruction error 0.470952
# >> Epoch 18 finished 	RBM Reconstruction error 0.459781
# >> Epoch 19 finished 	RBM Reconstruction error 0.469239
# >> Epoch 20 finished 	RBM Reconstruction error 0.478614
# >> Epoch 21 finished 	RBM Reconstruction error 0.498784
# >> Epoch 22 finished 	RBM Reconstruction error 0.496248
# >> Epoch 23 finished 	RBM Reconstruction error 0.500641
# >> Epoch 24 finished 	RBM Reconstruction error 0.455119
# >> Epoch 25 finished 	RBM Reconstruction error 0.512808
# >> Epoch 26 finished 	RBM Reconstruction error 0.487442
# >> Epoch 27 finished 	RBM Reconstruction error 0.501665
# >> Epoch 28 finished 	RBM Reconstruction error 0.480162
# >> Epoch 29 finished 	RBM Reconstruction error 0.517713
# >> Epoch 30 finished 	RBM Reconstruction error 0.488400
# >> Epoch 31 finished 	RBM Reconstruction error 0.535893
# >> Epoch 32 finished 	RBM Reconstruction error 0.500119
# >> Epoch 33 finished 	RBM Reconstruction error 0.497984
# >> Epoch 34 finished 	RBM Reconstruction error 0.521269
# >> Epoch 35 finished 	RBM Reconstruction error 0.539545
# >> Epoch 36 finished 	RBM Reconstruction error 0.546924
# >> Epoch 37 finished 	RBM Reconstruction error 0.492343
# >> Epoch 38 finished 	RBM Reconstruction error 0.521658
# >> Epoch 39 finished 	RBM Reconstruction error 0.500824
# >> Epoch 40 finished 	RBM Reconstruction error 0.466413
# >> Epoch 41 finished 	RBM Reconstruction error 0.482677
# >> Epoch 42 finished 	RBM Reconstruction error 0.495486
# >> Epoch 43 finished 	RBM Reconstruction error 0.491012
# >> Epoch 44 finished 	RBM Reconstruction error 0.535833
# >> Epoch 45 finished 	RBM Reconstruction error 0.503666
# >> Epoch 46 finished 	RBM Reconstruction error 0.484529
# >> Epoch 47 finished 	RBM Reconstruction error 0.472551
# >> Epoch 48 finished 	RBM Reconstruction error 0.480953
# >> Epoch 49 finished 	RBM Reconstruction error 0.514215
# >> Epoch 50 finished 	RBM Reconstruction error 0.471620
# >> Epoch 51 finished 	RBM Reconstruction error 0.515980
# >> Epoch 52 finished 	RBM Reconstruction error 0.475199
# >> Epoch 53 finished 	RBM Reconstruction error 0.448588
# >> Epoch 54 finished 	RBM Reconstruction error 0.482612
# >> Epoch 55 finished 	RBM Reconstruction error 0.498634
# >> Epoch 56 finished 	RBM Reconstruction error 0.480136
# >> Epoch 57 finished 	RBM Reconstruction error 0.469203
# >> Epoch 58 finished 	RBM Reconstruction error 0.482134
# >> Epoch 59 finished 	RBM Reconstruction error 0.441945
# >> Epoch 60 finished 	RBM Reconstruction error 0.457984
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 0.028207
# >> Epoch 2 finished 	ANN training loss 0.020657
# >> Epoch 3 finished 	ANN training loss 0.015724
# >> Epoch 4 finished 	ANN training loss 0.012072
# >> Epoch 5 finished 	ANN training loss 0.009349
# >> Epoch 6 finished 	ANN training loss 0.007285
# >> Epoch 7 finished 	ANN training loss 0.005738
# >> Epoch 8 finished 	ANN training loss 0.004574
# >> Epoch 9 finished 	ANN training loss 0.003688
# >> Epoch 10 finished 	ANN training loss 0.003009
# >> Epoch 11 finished 	ANN training loss 0.002489
# >> Epoch 12 finished 	ANN training loss 0.002093
# >> Epoch 13 finished 	ANN training loss 0.001789
# >> Epoch 14 finished 	ANN training loss 0.001555
# >> Epoch 15 finished 	ANN training loss 0.001376
# >> Epoch 16 finished 	ANN training loss 0.001239
# >> Epoch 17 finished 	ANN training loss 0.001132
# >> Epoch 18 finished 	ANN training loss 0.001050
# >> Epoch 19 finished 	ANN training loss 0.000986
# >> Epoch 20 finished 	ANN training loss 0.000937
# >> Epoch 21 finished 	ANN training loss 0.000898
# >> Epoch 22 finished 	ANN training loss 0.000868
# >> Epoch 23 finished 	ANN training loss 0.000844
# >> Epoch 24 finished 	ANN training loss 0.000826
# >> Epoch 25 finished 	ANN training loss 0.000811
# >> Epoch 26 finished 	ANN training loss 0.000798
# >> Epoch 27 finished 	ANN training loss 0.000790
# >> Epoch 28 finished 	ANN training loss 0.000781
# >> Epoch 29 finished 	ANN training loss 0.000775
# >> Epoch 30 finished 	ANN training loss 0.000769
# >> Epoch 31 finished 	ANN training loss 0.000764
# >> Epoch 32 finished 	ANN training loss 0.000760
# >> Epoch 33 finished 	ANN training loss 0.000757
# >> Epoch 34 finished 	ANN training loss 0.000754
# >> Epoch 35 finished 	ANN training loss 0.000750
# >> Epoch 36 finished 	ANN training loss 0.000747
# >> Epoch 37 finished 	ANN training loss 0.000745
# >> Epoch 38 finished 	ANN training loss 0.000742
# >> Epoch 39 finished 	ANN training loss 0.000740
# >> Epoch 40 finished 	ANN training loss 0.000738
# >> Epoch 41 finished 	ANN training loss 0.000736
# >> Epoch 42 finished 	ANN training loss 0.000734
# >> Epoch 43 finished 	ANN training loss 0.000732
# >> Epoch 44 finished 	ANN training loss 0.000730
# >> Epoch 45 finished 	ANN training loss 0.000727
# >> Epoch 46 finished 	ANN training loss 0.000725
# >> Epoch 47 finished 	ANN training loss 0.000723
# >> Epoch 48 finished 	ANN training loss 0.000722
# >> Epoch 49 finished 	ANN training loss 0.000720
# >> Epoch 50 finished 	ANN training loss 0.000718
# >> Epoch 51 finished 	ANN training loss 0.000716
# >> Epoch 52 finished 	ANN training loss 0.000714
# >> Epoch 53 finished 	ANN training loss 0.000712
# >> Epoch 54 finished 	ANN training loss 0.000710
# >> Epoch 55 finished 	ANN training loss 0.000708
# >> Epoch 56 finished 	ANN training loss 0.000707
# >> Epoch 57 finished 	ANN training loss 0.000704
# >> Epoch 58 finished 	ANN training loss 0.000703
# >> Epoch 59 finished 	ANN training loss 0.000701
# >> Epoch 60 finished 	ANN training loss 0.000699
# >> Epoch 61 finished 	ANN training loss 0.000698
# >> Epoch 62 finished 	ANN training loss 0.000696
# >> Epoch 63 finished 	ANN training loss 0.000694
# >> Epoch 64 finished 	ANN training loss 0.000692
# >> Epoch 65 finished 	ANN training loss 0.000691
# >> Epoch 66 finished 	ANN training loss 0.000689
# >> Epoch 67 finished 	ANN training loss 0.000687
# >> Epoch 68 finished 	ANN training loss 0.000686
# >> Epoch 69 finished 	ANN training loss 0.000684
# >> Epoch 70 finished 	ANN training loss 0.000683
# >> Epoch 71 finished 	ANN training loss 0.000681
# >> Epoch 72 finished 	ANN training loss 0.000679
# >> Epoch 73 finished 	ANN training loss 0.000678
# >> Epoch 74 finished 	ANN training loss 0.000676
# >> Epoch 75 finished 	ANN training loss 0.000674
# >> Epoch 76 finished 	ANN training loss 0.000673
# >> Epoch 77 finished 	ANN training loss 0.000671
# >> Epoch 78 finished 	ANN training loss 0.000670
# >> Epoch 79 finished 	ANN training loss 0.000668
# >> Epoch 80 finished 	ANN training loss 0.000666
# >> Epoch 81 finished 	ANN training loss 0.000664
# >> Epoch 82 finished 	ANN training loss 0.000663
# >> Epoch 83 finished 	ANN training loss 0.000662
# >> Epoch 84 finished 	ANN training loss 0.000660
# >> Epoch 85 finished 	ANN training loss 0.000659
# >> Epoch 86 finished 	ANN training loss 0.000657
# >> Epoch 87 finished 	ANN training loss 0.000656
# >> Epoch 88 finished 	ANN training loss 0.000654
# >> Epoch 89 finished 	ANN training loss 0.000653
# >> Epoch 90 finished 	ANN training loss 0.000652
# >> Epoch 91 finished 	ANN training loss 0.000650
# >> Epoch 92 finished 	ANN training loss 0.000648
# >> Epoch 93 finished 	ANN training loss 0.000647
# >> Epoch 94 finished 	ANN training loss 0.000646
# >> Epoch 95 finished 	ANN training loss 0.000644
# >> Epoch 96 finished 	ANN training loss 0.000642
# >> Epoch 97 finished 	ANN training loss 0.000641
# >> Epoch 98 finished 	ANN training loss 0.000640
# >> Epoch 99 finished 	ANN training loss 0.000638
# >> Epoch 100 finished 	ANN training loss 0.000637
# [END] Fine tuning step
# SupervisedDBNRegression()

# %%
test = scaler.transform(np.array(test).reshape(-1,1))

# %%
backcheck = 60
X_test , y_test = [] , []
for i in range(backcheck , len(test)):
    X_test.append(test[i-backcheck : i,0])
    y_test.append(test[i ,0])
    
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
preds = regressor.predict(X_test)

# %%
print(scaler.inverse_transform(preds))
print(scaler.inverse_transform(np.array(y_test).reshape(-1,1)))
# Out:
# [[ 7872.7493404 ]
#  [ 7861.90614997]
#  [ 7846.39105399]
#  ...
#  [14751.63326223]
#  [14765.98840231]
#  [14797.07428932]]
# [[ 7309.2998]
#  [ 7276.7998]
#  [ 7422.4502]
#  ...
#  [14709.25  ]
#  [14583.7002]
#  [14735.7002]]

# %%
training_predictions = regressor.predict(X_train)

# %%
print('Mean Squared Error = {}'.format(mean_squared_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) , scaler.inverse_transform(training_predictions))))
print('Mean absolute Error = {}'.format(mean_absolute_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) , scaler.inverse_transform(training_predictions))))
# Out:
# Mean Squared Error = 52957.41248736483
# Mean absolute Error = 156.08640591142805

# %%
plt.figure(figsize=(25,10))
plt.plot(scaler.inverse_transform(training_predictions) , label='Training fit')
plt.plot(scaler.inverse_transform(np.array(y_train).reshape(-1,1)), label = 'Original Values')
plt.legend()
plt.show()

# %%
print('Mean Squared Error = {}'.format(mean_squared_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) , scaler.inverse_transform(preds))))
print('Mean absolute Error = {}'.format(mean_absolute_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) , scaler.inverse_transform(preds))))
# Out:
# Mean Squared Error = 375062.1615217642
# Mean absolute Error = 398.61914484370345

# %%
plt.figure(figsize=(25,10))
plt.plot(scaler.inverse_transform(preds) , label='Testing Predictions')
plt.plot(scaler.inverse_transform(np.array(y_test).reshape(-1,1)), label = 'Original Values')
plt.legend()
plt.show()

# %%
regressor.save('./models/NSE501.pkl')
