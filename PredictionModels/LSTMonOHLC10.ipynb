# %% [markdown]
# # Imports

# %%
import numpy as np

from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error , mean_squared_error , mean_absolute_percentage_error

import tensorflow as tf
from tensorflow.keras.layers import LSTM , Dropout , Dense
from tensorflow.keras.models import Sequential
import pandas_datareader as pdd
import datetime

import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/Equity/NSE50.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
df.drop(df[df['High']==df['Low']].index , axis=0 , inplace=True)
df.head()
# Out:
#            Ticker       Date      Time    Open    High    Low   Close  \
# Date
# 1995-11-03  NSE50 1995-11-03  00:00:00   994.0  1001.0  993.0  1000.0
# 1995-11-06  NSE50 1995-11-06  00:00:00  1002.0  1002.0  989.0   989.0
# 1995-11-07  NSE50 1995-11-07  00:00:00   987.0   987.0  977.0   978.0
# 1995-11-08  NSE50 1995-11-08  00:00:00   976.0   976.0  963.0   964.0
# 1995-11-09  NSE50 1995-11-09  00:00:00   960.0   960.0  952.0   953.0
#
#               Volume  OI
# Date
# 1995-11-03  12938015    0
# 1995-11-06   9711115    0
# 1995-11-07  10985070    0
# 1995-11-08   7272730    0
# 1995-11-09   7680380    0

# %%
df.drop(['Ticker' , 'Date' ,'Time', 'Volume' , 'OI '] , axis=1 , inplace=True)
df = df.loc['2011-01':]
data = df.copy()

# %%
# Training and testing data
train_size = int(len(data) *0.80)
train = data[:train_size]
test = data[train_size :]

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_close = scaler.fit_transform(np.array(train['Close']).reshape(-1,1))

# %%
scaled_open = scaler.transform(np.array(train['Open']).reshape(-1,1))
scaled_high = scaler.transform(np.array(train['High']).reshape(-1,1))
scaled_low = scaler.transform(np.array(train['Low']).reshape(-1,1))

# %%
open_list = []
close_list = []
high_list = []
low_list = []
for i in range(len(scaled_open)):
    open_list.append(scaled_open[i])
    high_list.append(scaled_high[i])
    low_list.append(scaled_low[i])
    close_list.append( scaled_close[i])

# %%
open_arr = np.array(open_list).reshape(-1,1)
high_arr = np.array(high_list).reshape(-1,1)
low_arr = np.array(low_list).reshape(-1,1)
close_arr = np.array(close_list).reshape(-1,1)

# %%
scaled_data = pd.DataFrame(open_arr , columns=['Open'])

# %%
scaled_data['High'] = high_arr
scaled_data['Low'] = low_arr
scaled_data['Close'] = close_arr

# %%
scaled_train = np.array(scaled_data)

# %%
X_train = []
y_train = []

for x in range(60,len(scaled_train)-1):
    temp = []
    for i in scaled_train[x-60 :x,]:
        temp.append(i[0] )
        temp.append(i[1])
        temp.append( i[2])
        temp.append(i[3])
        
    X_train.append(temp)
    
    y_train.append(scaled_train[x+1][3])

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_train[1] , y_train[0]
# Out:
# (array([0.22636669, 0.22752035, 0.21964607, 0.22269713, 0.22200213,
#         0.22200213, 0.21102122, 0.21344671, 0.21722751, 0.21849933,
#         0.20545427, 0.20906132, 0.20664967, 0.20947139, 0.18617516,
#         0.18909414, 0.1886354 , 0.18946247, 0.16634697, 0.16939104,
#         0.17009994, 0.1804762 , 0.16040477, 0.1681748 , 0.17456176,
#         0.18486858, 0.1622256 , 0.18334652, 0.18160903, 0.18258202,
#         0.16575623, 0.16786897, 0.1678968 , 0.17923213, 0.15226634,
#         0.15433741, 0.15353817, 0.16011978, 0.15011186, 0.15436524,
#         0.15822938, 0.16489441, 0.15665872, 0.16399784, 0.16584656,
#         0.16727822, 0.1554494 , 0.15941087, 0.15453899, 0.16474849,
#         0.15155051, 0.16226734, 0.15954987, 0.16309434, 0.15711047,
#         0.16016844, 0.16303184, 0.16843888, 0.16034219, 0.16666664,
#         0.16945354, 0.17477025, 0.1579653 , 0.15890354, 0.16417158,
#         0.16428283, 0.14605313, 0.14735271, 0.14870103, 0.14875662,
#         0.12723262, 0.13454398, 0.12625963, 0.13658729, 0.12126958,
#         0.13367523, 0.13803979, 0.13829695, 0.11923326, 0.12134607,
#         0.12862261, 0.13154858, 0.12113058, 0.12340323, 0.1231878 ,
#         0.13739345, 0.12145724, 0.13657337, 0.13562122, 0.14068077,
#         0.11465321, 0.11836451, 0.12314606, 0.12456388, 0.11575136,
#         0.11839926, 0.12345189, 0.12345189, 0.10552795, 0.10679978,
#         0.1040893 , 0.1105389 , 0.09472078, 0.09859884, 0.09755635,
#         0.10124681, 0.09071065, 0.09474162, 0.09388679, 0.10775892,
#         0.08805582, 0.10644536, 0.11065007, 0.12782336, 0.11065007,
#         0.1267392 , 0.12837244, 0.13375865, 0.12011591, 0.13021417,
#         0.1283516 , 0.13352232, 0.12734386, 0.1303115 , 0.13309148,
#         0.1402221 , 0.12776778, 0.13931168, 0.14085451, 0.1466508 ,
#         0.12478629, 0.12714927, 0.12682261, 0.13650387, 0.12077616,
#         0.13544055, 0.13346673, 0.13555871, 0.12413989, 0.12857401,
#         0.12624578, 0.13218799, 0.12278465, 0.12414688, 0.1201715 ,
#         0.12220782, 0.09706293, 0.09987073, 0.10798127, 0.11036515,
#         0.09570769, 0.10554878, 0.10924617, 0.12965818, 0.10625077,
#         0.10967708, 0.11645328, 0.13744904, 0.11527871, 0.1359548 ,
#         0.12985975, 0.14268933, 0.12844194, 0.13788694, 0.14483689,
#         0.14789487, 0.13620504, 0.13824136, 0.13147209, 0.13163891,
#         0.12012983, 0.12773303, 0.1281431 , 0.13710154, 0.12795544,
#         0.1357463 , 0.13874869, 0.14165376, 0.12972075, 0.13716412,
#         0.13509305, 0.13512081, 0.12846976, 0.13207674, 0.12676004,
#         0.13323048, 0.12056067, 0.12527279, 0.12402872, 0.13803979,
#         0.12371597, 0.13723362, 0.12173524, 0.13255632, 0.11529262,
#         0.12585654, 0.12951226, 0.13773403, 0.12951226, 0.13440498,
#         0.12665579, 0.13425206, 0.12386189, 0.12543955, 0.12942884,
#         0.13049909, 0.11428488, 0.11529962, 0.1201715 , 0.12080392,
#         0.11175514, 0.11405555, 0.11768343, 0.12286807, 0.11564012,
#         0.12088041, 0.12053983, 0.13076325, 0.11922634, 0.13010992,
#         0.13310532, 0.13688612, 0.13231307, 0.13596872, 0.14517739,
#         0.15608189, 0.14132717, 0.15429574, 0.15304475, 0.16191984,
#         0.15275983, 0.1588827 , 0.15877845, 0.17043353, 0.15797229,
#         0.16570756, 0.16841105, 0.17499267, 0.16814697, 0.17283818]),
#  0.17924604698847824)

# %%
test_scaled_close = scaler.transform(np.array(test['Close']).reshape(-1,1))
test_scaled_open = scaler.transform(np.array(test['Open']).reshape(-1,1))
test_scaled_high = scaler.transform(np.array(test['High']).reshape(-1,1))
test_scaled_low = scaler.transform(np.array(test['Low']).reshape(-1,1))

# %%
open_list = []
close_list = []
high_list = []
low_list = []
for i in range(len(test_scaled_open)):
    open_list.append(test_scaled_open[i])
    high_list.append(test_scaled_high[i])
    low_list.append(test_scaled_low[i])
    close_list.append( test_scaled_close[i])

# %%
open_arr = np.array(open_list).reshape(-1,1)
high_arr = np.array(high_list).reshape(-1,1)
low_arr = np.array(low_list).reshape(-1,1)
close_arr = np.array(close_list).reshape(-1,1)

# %%
scaled_data = pd.DataFrame(open_arr , columns=['Open'])
scaled_data['High'] = high_arr
scaled_data['Low'] = low_arr
scaled_data['Close'] = close_arr

# %%
scaled_test = np.array(scaled_data)

# %%
X_test = []
y_test = []

for x in range(60,len(scaled_test)-1):
    temp = []
    for i in scaled_test[x-60 :x,]:
        temp.append(i[0] )
        temp.append(i[1])
        temp.append( i[2])
        temp.append(i[3])
        
    X_test.append(temp)
    
    y_test.append(scaled_test[x+1][3])

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
lstm = Sequential()
lstm.add(LSTM(250 ,return_sequences=True ,  input_shape=(240,1)))
lstm.add(LSTM(250 , return_sequences = True))
lstm.add(LSTM(250))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error' , optimizer='adam' , metrics=['accuracy','mse'])

# %%
lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 240, 250)          252000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 240, 250)          501000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 250)               501000
# _________________________________________________________________
# dense (Dense)                (None, 1)                 251
# =================================================================
# Total params: 1,254,251
# Trainable params: 1,254,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train = X_train.reshape((-1,240 , 1))
y_train = y_train.reshape(-1,1)
X_test = X_test.reshape((-1,240,1))
y_train = y_train.reshape(-1,1)

# %%
callback = tf.keras.callbacks.ModelCheckpoint(filepath='./models/lstm10',
                                              save_weights_only=True,
                                              verbose=1)

# %%
lstm.fit(X_train ,y_train , validation_data=(X_test,y_test) ,epochs=100 , batch_size=64 ,verbose=1 , callbacks=[callback] )
# Out:
# Epoch 1/100
# 30/30 [==============================] - 74s 2s/step - loss: 0.1013 - accuracy: 7.1265e-04 - mse: 0.1013 - val_loss: 0.0348 - val_accuracy: 0.0000e+00 - val_mse: 0.0348
#
# Epoch 00001: saving model to ./models/lstm10
# Epoch 2/100
# 30/30 [==============================] - 65s 2s/step - loss: 0.0020 - accuracy: 0.0013 - mse: 0.0020 - val_loss: 0.0053 - val_accuracy: 0.0000e+00 - val_mse: 0.0053
#
# Epoch 00002: saving model to ./models/lstm10
# Epoch 3/100
# 30/30 [==============================] - 66s 2s/step - loss: 4.2688e-04 - accuracy: 7.7561e-04 - mse: 4.2688e-04 - val_loss: 0.0057 - val_accuracy: 0.0000e+00 - val_mse: 0.0057
#
# Epoch 00003: saving model to ./models/lstm10
# Epoch 4/100
# 30/30 [==============================] - 69s 2s/step - loss: 3.7196e-04 - accuracy: 5.9627e-04 - mse: 3.7196e-04 - val_loss: 0.0051 - val_accuracy: 0.0000e+00 - val_mse: 0.0051
#
# Epoch 00004: saving model to ./models/lstm10
# Epoch 5/100
# 30/30 [==============================] - 70s 2s/step - loss: 3.5677e-04 - accuracy: 0.0023 - mse: 3.5677e-04 - val_loss: 0.0049 - val_accuracy: 0.0000e+00 - val_mse: 0.0049
#
# Epoch 00005: saving model to ./models/lstm10
# Epoch 6/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.5327e-04 - accuracy: 4.4606e-04 - mse: 3.5327e-04 - val_loss: 0.0043 - val_accuracy: 0.0000e+00 - val_mse: 0.0043
#
# Epoch 00006: saving model to ./models/lstm10
# Epoch 7/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.4992e-04 - accuracy: 9.9338e-04 - mse: 3.4992e-04 - val_loss: 0.0043 - val_accuracy: 0.0000e+00 - val_mse: 0.0043
#
# Epoch 00007: saving model to ./models/lstm10
# Epoch 8/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.4405e-04 - accuracy: 0.0026 - mse: 3.4405e-04 - val_loss: 0.0048 - val_accuracy: 0.0000e+00 - val_mse: 0.0048
#
# Epoch 00008: saving model to ./models/lstm10
# Epoch 9/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.7127e-04 - accuracy: 0.0013 - mse: 3.7127e-04 - val_loss: 0.0042 - val_accuracy: 0.0000e+00 - val_mse: 0.0042
#
# Epoch 00009: saving model to ./models/lstm10
# Epoch 10/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.3685e-04 - accuracy: 2.6311e-04 - mse: 3.3685e-04 - val_loss: 0.0041 - val_accuracy: 0.0000e+00 - val_mse: 0.0041
#
# Epoch 00010: saving model to ./models/lstm10
# Epoch 11/100
# 30/30 [==============================] - 73s 2s/step - loss: 3.4710e-04 - accuracy: 4.4606e-04 - mse: 3.4710e-04 - val_loss: 0.0041 - val_accuracy: 0.0000e+00 - val_mse: 0.0041
#
# Epoch 00011: saving model to ./models/lstm10
# Epoch 12/100
# 30/30 [==============================] - 83s 3s/step - loss: 3.3674e-04 - accuracy: 6.8937e-04 - mse: 3.3674e-04 - val_loss: 0.0042 - val_accuracy: 0.0000e+00 - val_mse: 0.0042
#
# Epoch 00012: saving model to ./models/lstm10
# Epoch 13/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.5344e-04 - accuracy: 5.0099e-04 - mse: 3.5344e-04 - val_loss: 0.0044 - val_accuracy: 0.0000e+00 - val_mse: 0.0044
#
# Epoch 00013: saving model to ./models/lstm10
# Epoch 14/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.4392e-04 - accuracy: 6.8441e-04 - mse: 3.4392e-04 - val_loss: 0.0045 - val_accuracy: 0.0000e+00 - val_mse: 0.0045
#
# Epoch 00014: saving model to ./models/lstm10
# Epoch 15/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.7876e-04 - accuracy: 0.0013 - mse: 3.7876e-04 - val_loss: 0.0045 - val_accuracy: 0.0000e+00 - val_mse: 0.0045
#
# Epoch 00015: saving model to ./models/lstm10
# Epoch 16/100
# 30/30 [==============================] - 65s 2s/step - loss: 4.0919e-04 - accuracy: 4.6036e-04 - mse: 4.0919e-04 - val_loss: 0.0040 - val_accuracy: 0.0000e+00 - val_mse: 0.0040
#
# Epoch 00016: saving model to ./models/lstm10
# Epoch 17/100
# 30/30 [==============================] - 70s 2s/step - loss: 3.7016e-04 - accuracy: 0.0023 - mse: 3.7016e-04 - val_loss: 0.0055 - val_accuracy: 0.0000e+00 - val_mse: 0.0055
#
# Epoch 00017: saving model to ./models/lstm10
# Epoch 18/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.6713e-04 - accuracy: 0.0010 - mse: 3.6713e-04 - val_loss: 0.0042 - val_accuracy: 0.0000e+00 - val_mse: 0.0042
#
# Epoch 00018: saving model to ./models/lstm10
# Epoch 19/100
# 30/30 [==============================] - 72s 2s/step - loss: 3.4383e-04 - accuracy: 0.0013 - mse: 3.4383e-04 - val_loss: 0.0042 - val_accuracy: 0.0000e+00 - val_mse: 0.0042
#
# Epoch 00019: saving model to ./models/lstm10
# Epoch 20/100
# 30/30 [==============================] - 68s 2s/step - loss: 3.5958e-04 - accuracy: 0.0020 - mse: 3.5958e-04 - val_loss: 0.0043 - val_accuracy: 0.0000e+00 - val_mse: 0.0043
#
# Epoch 00020: saving model to ./models/lstm10
# Epoch 21/100
# 30/30 [==============================] - 68s 2s/step - loss: 3.4477e-04 - accuracy: 5.0721e-04 - mse: 3.4477e-04 - val_loss: 0.0039 - val_accuracy: 0.0000e+00 - val_mse: 0.0039
#
# Epoch 00021: saving model to ./models/lstm10
# Epoch 22/100
# 30/30 [==============================] - 68s 2s/step - loss: 3.6047e-04 - accuracy: 0.0012 - mse: 3.6047e-04 - val_loss: 0.0039 - val_accuracy: 0.0000e+00 - val_mse: 0.0039
#
# Epoch 00022: saving model to ./models/lstm10
# Epoch 23/100
# 30/30 [==============================] - 64s 2s/step - loss: 3.4908e-04 - accuracy: 3.6424e-04 - mse: 3.4908e-04 - val_loss: 0.0040 - val_accuracy: 0.0000e+00 - val_mse: 0.0040
#
# Epoch 00023: saving model to ./models/lstm10
# Epoch 24/100
# 30/30 [==============================] - 64s 2s/step - loss: 3.3853e-04 - accuracy: 0.0011 - mse: 3.3853e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00024: saving model to ./models/lstm10
# Epoch 25/100
# 30/30 [==============================] - 64s 2s/step - loss: 3.6963e-04 - accuracy: 0.0023 - mse: 3.6963e-04 - val_loss: 0.0044 - val_accuracy: 0.0000e+00 - val_mse: 0.0044
#
# Epoch 00025: saving model to ./models/lstm10
# Epoch 26/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.9855e-04 - accuracy: 0.0010 - mse: 3.9855e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00026: saving model to ./models/lstm10
# Epoch 27/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.2799e-04 - accuracy: 8.8162e-04 - mse: 3.2799e-04 - val_loss: 0.0039 - val_accuracy: 0.0000e+00 - val_mse: 0.0039
#
# Epoch 00027: saving model to ./models/lstm10
# Epoch 28/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.6030e-04 - accuracy: 0.0016 - mse: 3.6030e-04 - val_loss: 0.0037 - val_accuracy: 0.0000e+00 - val_mse: 0.0037
#
# Epoch 00028: saving model to ./models/lstm10
# Epoch 29/100
# 30/30 [==============================] - 69s 2s/step - loss: 3.3238e-04 - accuracy: 0.0013 - mse: 3.3238e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00029: saving model to ./models/lstm10
# Epoch 30/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.6298e-04 - accuracy: 0.0014 - mse: 3.6298e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00030: saving model to ./models/lstm10
# Epoch 31/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.3916e-04 - accuracy: 6.2420e-04 - mse: 3.3916e-04 - val_loss: 0.0049 - val_accuracy: 0.0000e+00 - val_mse: 0.0049
#
# Epoch 00031: saving model to ./models/lstm10
# Epoch 32/100
# 30/30 [==============================] - 68s 2s/step - loss: 4.3157e-04 - accuracy: 5.2913e-04 - mse: 4.3157e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00032: saving model to ./models/lstm10
# Epoch 33/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.1443e-04 - accuracy: 4.9762e-04 - mse: 3.1443e-04 - val_loss: 0.0039 - val_accuracy: 0.0000e+00 - val_mse: 0.0039
#
# Epoch 00033: saving model to ./models/lstm10
# Epoch 34/100
# 30/30 [==============================] - 71s 2s/step - loss: 3.9260e-04 - accuracy: 8.5890e-04 - mse: 3.9260e-04 - val_loss: 0.0036 - val_accuracy: 0.0000e+00 - val_mse: 0.0036
#
# Epoch 00034: saving model to ./models/lstm10
# Epoch 35/100
# 30/30 [==============================] - 72s 2s/step - loss: 3.8430e-04 - accuracy: 8.5890e-04 - mse: 3.8430e-04 - val_loss: 0.0036 - val_accuracy: 0.0000e+00 - val_mse: 0.0036
#
# Epoch 00035: saving model to ./models/lstm10
# Epoch 36/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.6952e-04 - accuracy: 7.9361e-04 - mse: 3.6952e-04 - val_loss: 0.0036 - val_accuracy: 0.0000e+00 - val_mse: 0.0036
#
# Epoch 00036: saving model to ./models/lstm10
# Epoch 37/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.2942e-04 - accuracy: 9.0385e-04 - mse: 3.2942e-04 - val_loss: 0.0036 - val_accuracy: 0.0000e+00 - val_mse: 0.0036
#
# Epoch 00037: saving model to ./models/lstm10
# Epoch 38/100
# 30/30 [==============================] - 69s 2s/step - loss: 3.1732e-04 - accuracy: 9.7568e-04 - mse: 3.1732e-04 - val_loss: 0.0035 - val_accuracy: 0.0000e+00 - val_mse: 0.0035
#
# Epoch 00038: saving model to ./models/lstm10
# Epoch 39/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.0649e-04 - accuracy: 0.0014 - mse: 3.0649e-04 - val_loss: 0.0036 - val_accuracy: 0.0000e+00 - val_mse: 0.0036
#
# Epoch 00039: saving model to ./models/lstm10
# Epoch 40/100
# 30/30 [==============================] - 67s 2s/step - loss: 2.9956e-04 - accuracy: 0.0012 - mse: 2.9956e-04 - val_loss: 0.0042 - val_accuracy: 0.0000e+00 - val_mse: 0.0042
#
# Epoch 00040: saving model to ./models/lstm10
# Epoch 41/100
# 30/30 [==============================] - 86s 3s/step - loss: 4.3020e-04 - accuracy: 0.0013 - mse: 4.3020e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00041: saving model to ./models/lstm10
# Epoch 42/100
# 30/30 [==============================] - 70s 2s/step - loss: 3.7734e-04 - accuracy: 0.0013 - mse: 3.7734e-04 - val_loss: 0.0035 - val_accuracy: 0.0000e+00 - val_mse: 0.0035
#
# Epoch 00042: saving model to ./models/lstm10
# Epoch 43/100
# 30/30 [==============================] - 69s 2s/step - loss: 3.2672e-04 - accuracy: 6.7460e-04 - mse: 3.2672e-04 - val_loss: 0.0039 - val_accuracy: 0.0000e+00 - val_mse: 0.0039
#
# Epoch 00043: saving model to ./models/lstm10
# Epoch 44/100
# 30/30 [==============================] - 73s 2s/step - loss: 3.2506e-04 - accuracy: 7.2642e-04 - mse: 3.2506e-04 - val_loss: 0.0035 - val_accuracy: 0.0000e+00 - val_mse: 0.0035
#
# Epoch 00044: saving model to ./models/lstm10
# Epoch 45/100
# 30/30 [==============================] - 74s 2s/step - loss: 3.4374e-04 - accuracy: 7.7573e-04 - mse: 3.4374e-04 - val_loss: 0.0035 - val_accuracy: 0.0000e+00 - val_mse: 0.0035
#
# Epoch 00045: saving model to ./models/lstm10
# Epoch 46/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.2898e-04 - accuracy: 9.4165e-04 - mse: 3.2898e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00046: saving model to ./models/lstm10
# Epoch 47/100
# 30/30 [==============================] - 68s 2s/step - loss: 3.3150e-04 - accuracy: 0.0010 - mse: 3.3150e-04 - val_loss: 0.0040 - val_accuracy: 0.0000e+00 - val_mse: 0.0040
#
# Epoch 00047: saving model to ./models/lstm10
# Epoch 48/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.5288e-04 - accuracy: 0.0025 - mse: 3.5288e-04 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - val_mse: 0.0034
#
# Epoch 00048: saving model to ./models/lstm10
# Epoch 49/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.2236e-04 - accuracy: 0.0015 - mse: 3.2236e-04 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - val_mse: 0.0034
#
# Epoch 00049: saving model to ./models/lstm10
# Epoch 50/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.2325e-04 - accuracy: 2.7693e-04 - mse: 3.2325e-04 - val_loss: 0.0037 - val_accuracy: 0.0000e+00 - val_mse: 0.0037
#
# Epoch 00050: saving model to ./models/lstm10
# Epoch 51/100
# 30/30 [==============================] - 65s 2s/step - loss: 2.9061e-04 - accuracy: 0.0013 - mse: 2.9061e-04 - val_loss: 0.0039 - val_accuracy: 0.0000e+00 - val_mse: 0.0039
#
# Epoch 00051: saving model to ./models/lstm10
# Epoch 52/100
# 30/30 [==============================] - 69s 2s/step - loss: 3.2627e-04 - accuracy: 0.0017 - mse: 3.2627e-04 - val_loss: 0.0037 - val_accuracy: 0.0000e+00 - val_mse: 0.0037
#
# Epoch 00052: saving model to ./models/lstm10
# Epoch 53/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.3053e-04 - accuracy: 4.7960e-04 - mse: 3.3053e-04 - val_loss: 0.0035 - val_accuracy: 0.0000e+00 - val_mse: 0.0035
#
# Epoch 00053: saving model to ./models/lstm10
# Epoch 54/100
# 30/30 [==============================] - 69s 2s/step - loss: 3.3020e-04 - accuracy: 8.1227e-04 - mse: 3.3020e-04 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - val_mse: 0.0034
#
# Epoch 00054: saving model to ./models/lstm10
# Epoch 55/100
# 30/30 [==============================] - 81s 3s/step - loss: 2.9501e-04 - accuracy: 8.2013e-04 - mse: 2.9501e-04 - val_loss: 0.0035 - val_accuracy: 0.0000e+00 - val_mse: 0.0035
#
# Epoch 00055: saving model to ./models/lstm10
# Epoch 56/100
# 30/30 [==============================] - 80s 3s/step - loss: 3.4133e-04 - accuracy: 0.0011 - mse: 3.4133e-04 - val_loss: 0.0033 - val_accuracy: 0.0000e+00 - val_mse: 0.0033
#
# Epoch 00056: saving model to ./models/lstm10
# Epoch 57/100
# 30/30 [==============================] - 84s 3s/step - loss: 3.6199e-04 - accuracy: 0.0016 - mse: 3.6199e-04 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - val_mse: 0.0034
#
# Epoch 00057: saving model to ./models/lstm10
# Epoch 58/100
# 30/30 [==============================] - 73s 2s/step - loss: 2.7808e-04 - accuracy: 5.7837e-04 - mse: 2.7808e-04 - val_loss: 0.0033 - val_accuracy: 0.0000e+00 - val_mse: 0.0033
#
# Epoch 00058: saving model to ./models/lstm10
# Epoch 59/100
# 30/30 [==============================] - 74s 2s/step - loss: 3.0932e-04 - accuracy: 8.9474e-04 - mse: 3.0932e-04 - val_loss: 0.0045 - val_accuracy: 0.0000e+00 - val_mse: 0.0045
#
# Epoch 00059: saving model to ./models/lstm10
# Epoch 60/100
# 30/30 [==============================] - 66s 2s/step - loss: 3.8793e-04 - accuracy: 0.0013 - mse: 3.8793e-04 - val_loss: 0.0035 - val_accuracy: 0.0000e+00 - val_mse: 0.0035
#
# Epoch 00060: saving model to ./models/lstm10
# Epoch 61/100
# 30/30 [==============================] - 65s 2s/step - loss: 2.8646e-04 - accuracy: 0.0011 - mse: 2.8646e-04 - val_loss: 0.0036 - val_accuracy: 0.0000e+00 - val_mse: 0.0036
#
# Epoch 00061: saving model to ./models/lstm10
# Epoch 62/100
# 30/30 [==============================] - 65s 2s/step - loss: 2.8364e-04 - accuracy: 9.4165e-04 - mse: 2.8364e-04 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - val_mse: 0.0034
#
# Epoch 00062: saving model to ./models/lstm10
# Epoch 63/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.4805e-04 - accuracy: 0.0011 - mse: 3.4805e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00063: saving model to ./models/lstm10
# Epoch 64/100
# 30/30 [==============================] - 72s 2s/step - loss: 2.9452e-04 - accuracy: 3.8551e-04 - mse: 2.9452e-04 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - val_mse: 0.0034
#
# Epoch 00064: saving model to ./models/lstm10
# Epoch 65/100
# 30/30 [==============================] - 64s 2s/step - loss: 2.8293e-04 - accuracy: 0.0017 - mse: 2.8293e-04 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - val_mse: 0.0034
#
# Epoch 00065: saving model to ./models/lstm10
# Epoch 66/100
# 30/30 [==============================] - 64s 2s/step - loss: 2.7956e-04 - accuracy: 0.0020 - mse: 2.7956e-04 - val_loss: 0.0032 - val_accuracy: 0.0000e+00 - val_mse: 0.0032
#
# Epoch 00066: saving model to ./models/lstm10
# Epoch 67/100
# 30/30 [==============================] - 67s 2s/step - loss: 2.9115e-04 - accuracy: 0.0017 - mse: 2.9115e-04 - val_loss: 0.0032 - val_accuracy: 0.0000e+00 - val_mse: 0.0032
#
# Epoch 00067: saving model to ./models/lstm10
# Epoch 68/100
# 30/30 [==============================] - 67s 2s/step - loss: 3.3510e-04 - accuracy: 8.1227e-04 - mse: 3.3510e-04 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - val_mse: 0.0038
#
# Epoch 00068: saving model to ./models/lstm10
# Epoch 69/100
# 30/30 [==============================] - 73s 2s/step - loss: 2.8296e-04 - accuracy: 0.0013 - mse: 2.8296e-04 - val_loss: 0.0032 - val_accuracy: 0.0000e+00 - val_mse: 0.0032
#
# Epoch 00069: saving model to ./models/lstm10
# Epoch 70/100
# 30/30 [==============================] - 81s 3s/step - loss: 2.9628e-04 - accuracy: 1.3974e-04 - mse: 2.9628e-04 - val_loss: 0.0040 - val_accuracy: 0.0000e+00 - val_mse: 0.0040
#
# Epoch 00070: saving model to ./models/lstm10
# Epoch 71/100
# 30/30 [==============================] - 69s 2s/step - loss: 3.6080e-04 - accuracy: 0.0011 - mse: 3.6080e-04 - val_loss: 0.0032 - val_accuracy: 0.0000e+00 - val_mse: 0.0032
#
# Epoch 00071: saving model to ./models/lstm10
# Epoch 72/100
# 30/30 [==============================] - 72s 2s/step - loss: 2.9557e-04 - accuracy: 7.6415e-04 - mse: 2.9557e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00072: saving model to ./models/lstm10
# Epoch 73/100
# 30/30 [==============================] - 70s 2s/step - loss: 2.8161e-04 - accuracy: 0.0018 - mse: 2.8161e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00073: saving model to ./models/lstm10
# Epoch 74/100
# 30/30 [==============================] - 85s 3s/step - loss: 3.1118e-04 - accuracy: 6.3659e-04 - mse: 3.1118e-04 - val_loss: 0.0037 - val_accuracy: 0.0000e+00 - val_mse: 0.0037
#
# Epoch 00074: saving model to ./models/lstm10
# Epoch 75/100
# 30/30 [==============================] - 94s 3s/step - loss: 2.9972e-04 - accuracy: 0.0010 - mse: 2.9972e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00075: saving model to ./models/lstm10
# Epoch 76/100
# 30/30 [==============================] - 76s 3s/step - loss: 2.8464e-04 - accuracy: 0.0017 - mse: 2.8464e-04 - val_loss: 0.0032 - val_accuracy: 0.0000e+00 - val_mse: 0.0032
#
# Epoch 00076: saving model to ./models/lstm10
# Epoch 77/100
# 30/30 [==============================] - 66s 2s/step - loss: 2.7330e-04 - accuracy: 4.2800e-04 - mse: 2.7330e-04 - val_loss: 0.0036 - val_accuracy: 0.0000e+00 - val_mse: 0.0036
#
# Epoch 00077: saving model to ./models/lstm10
# Epoch 78/100
# 30/30 [==============================] - 64s 2s/step - loss: 2.7370e-04 - accuracy: 0.0013 - mse: 2.7370e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00078: saving model to ./models/lstm10
# Epoch 79/100
# 30/30 [==============================] - 65s 2s/step - loss: 2.7470e-04 - accuracy: 0.0011 - mse: 2.7470e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00079: saving model to ./models/lstm10
# Epoch 80/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.1807e-04 - accuracy: 0.0013 - mse: 3.1807e-04 - val_loss: 0.0037 - val_accuracy: 0.0000e+00 - val_mse: 0.0037
#
# Epoch 00080: saving model to ./models/lstm10
# Epoch 81/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.0650e-04 - accuracy: 6.8441e-04 - mse: 3.0650e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00081: saving model to ./models/lstm10
# Epoch 82/100
# 30/30 [==============================] - 65s 2s/step - loss: 2.7372e-04 - accuracy: 5.2053e-04 - mse: 2.7372e-04 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - val_mse: 0.0034
#
# Epoch 00082: saving model to ./models/lstm10
# Epoch 83/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.2076e-04 - accuracy: 3.8551e-04 - mse: 3.2076e-04 - val_loss: 0.0030 - val_accuracy: 0.0000e+00 - val_mse: 0.0030
#
# Epoch 00083: saving model to ./models/lstm10
# Epoch 84/100
# 30/30 [==============================] - 65s 2s/step - loss: 2.7808e-04 - accuracy: 7.5822e-04 - mse: 2.7808e-04 - val_loss: 0.0036 - val_accuracy: 0.0000e+00 - val_mse: 0.0036
#
# Epoch 00084: saving model to ./models/lstm10
# Epoch 85/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.3556e-04 - accuracy: 0.0025 - mse: 3.3556e-04 - val_loss: 0.0042 - val_accuracy: 0.0000e+00 - val_mse: 0.0042
#
# Epoch 00085: saving model to ./models/lstm10
# Epoch 86/100
# 30/30 [==============================] - 65s 2s/step - loss: 3.1142e-04 - accuracy: 0.0025 - mse: 3.1142e-04 - val_loss: 0.0029 - val_accuracy: 0.0000e+00 - val_mse: 0.0029
#
# Epoch 00086: saving model to ./models/lstm10
# Epoch 87/100
# 30/30 [==============================] - 64s 2s/step - loss: 2.4210e-04 - accuracy: 0.0010 - mse: 2.4210e-04 - val_loss: 0.0030 - val_accuracy: 0.0000e+00 - val_mse: 0.0030
#
# Epoch 00087: saving model to ./models/lstm10
# Epoch 88/100
# 30/30 [==============================] - 65s 2s/step - loss: 2.6469e-04 - accuracy: 0.0022 - mse: 2.6469e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00088: saving model to ./models/lstm10
# Epoch 89/100
# 30/30 [==============================] - 65s 2s/step - loss: 2.6248e-04 - accuracy: 0.0011 - mse: 2.6248e-04 - val_loss: 0.0029 - val_accuracy: 0.0000e+00 - val_mse: 0.0029
#
# Epoch 00089: saving model to ./models/lstm10
# Epoch 90/100
# 30/30 [==============================] - 67s 2s/step - loss: 2.8400e-04 - accuracy: 3.5751e-04 - mse: 2.8400e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00090: saving model to ./models/lstm10
# Epoch 91/100
# 30/30 [==============================] - 93s 3s/step - loss: 2.5310e-04 - accuracy: 0.0016 - mse: 2.5310e-04 - val_loss: 0.0030 - val_accuracy: 0.0000e+00 - val_mse: 0.0030
#
# Epoch 00091: saving model to ./models/lstm10
# Epoch 92/100
# 30/30 [==============================] - 78s 3s/step - loss: 3.5467e-04 - accuracy: 3.7849e-04 - mse: 3.5467e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00092: saving model to ./models/lstm10
# Epoch 93/100
# 30/30 [==============================] - 71s 2s/step - loss: 3.5398e-04 - accuracy: 5.7837e-04 - mse: 3.5398e-04 - val_loss: 0.0029 - val_accuracy: 0.0000e+00 - val_mse: 0.0029
#
# Epoch 00093: saving model to ./models/lstm10
# Epoch 94/100
# 30/30 [==============================] - 74s 2s/step - loss: 2.5526e-04 - accuracy: 0.0019 - mse: 2.5526e-04 - val_loss: 0.0032 - val_accuracy: 0.0000e+00 - val_mse: 0.0032
#
# Epoch 00094: saving model to ./models/lstm10
# Epoch 95/100
# 30/30 [==============================] - 80s 3s/step - loss: 3.0752e-04 - accuracy: 7.5502e-04 - mse: 3.0752e-04 - val_loss: 0.0032 - val_accuracy: 0.0000e+00 - val_mse: 0.0032
#
# Epoch 00095: saving model to ./models/lstm10
# Epoch 96/100
# 30/30 [==============================] - 81s 3s/step - loss: 2.8294e-04 - accuracy: 0.0014 - mse: 2.8294e-04 - val_loss: 0.0029 - val_accuracy: 0.0000e+00 - val_mse: 0.0029
#
# Epoch 00096: saving model to ./models/lstm10
# Epoch 97/100
# 30/30 [==============================] - 88s 3s/step - loss: 2.8735e-04 - accuracy: 3.6111e-04 - mse: 2.8735e-04 - val_loss: 0.0028 - val_accuracy: 0.0000e+00 - val_mse: 0.0028
#
# Epoch 00097: saving model to ./models/lstm10
# Epoch 98/100
# 30/30 [==============================] - 87s 3s/step - loss: 2.7316e-04 - accuracy: 0.0011 - mse: 2.7316e-04 - val_loss: 0.0028 - val_accuracy: 0.0000e+00 - val_mse: 0.0028
#
# Epoch 00098: saving model to ./models/lstm10
# Epoch 99/100
# 30/30 [==============================] - 85s 3s/step - loss: 2.4914e-04 - accuracy: 4.2622e-04 - mse: 2.4914e-04 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - val_mse: 0.0031
#
# Epoch 00099: saving model to ./models/lstm10
# Epoch 100/100
# 30/30 [==============================] - 68s 2s/step - loss: 3.1786e-04 - accuracy: 0.0018 - mse: 3.1786e-04 - val_loss: 0.0029 - val_accuracy: 0.0000e+00 - val_mse: 0.0029
#
# Epoch 00100: saving model to ./models/lstm10

# %%
lstm= tf.keras.models.load_model('./models/lstm10.h5')

# %%
training_predictions = lstm.predict(X_train)

# %%
print('Mean Squared Error : {}'.format(mean_squared_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,scaler.inverse_transform(training_predictions) )))
print('Mean Absolute Error : {}'.format(mean_absolute_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,scaler.inverse_transform(training_predictions))))
# Out:
# Mean Squared Error : 12193.882368154236
# Mean Absolute Error : 86.1369714730016

# %%
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(training_predictions) , label='Training Fitting')
plt.plot(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,label='Original Values')
plt.legend()
plt.show()

# %%
preds = lstm.predict(X_test)

# %%
print('Mean Squared Error : {}'.format(mean_squared_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,scaler.inverse_transform(preds) )))
print('Mean Absolute Error : {}'.format(mean_absolute_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,scaler.inverse_transform(preds))))
# Out:
# Mean Squared Error : 148716.84554593105
# Mean Absolute Error : 201.1174058676083

# %%
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(preds) , label='Testing Prediction')
plt.plot(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,label='Original')
plt.legend()
plt.show()

# %%
# lstm.save_weights('./models/lstm240.weights')
lstm.save('./models/lstm10.h5')

# %%
lstm2 = tf.keras.models.load_model('./models/lstm240.h5')

# %%
lstm2_preds = lstm2.predict(X_test)

# %%
scaled_original = scaler.inverse_transform(np.array(y_test).reshape(-1,1))
scaled_lstm10 = scaler.inverse_transform(preds)
scaled_lstm25 = scaler.inverse_transform(lstm2_preds)

# %%
scaled_original = scaled_original.reshape(1,-1).tolist()
scaled_lstm10  = scaled_lstm10.reshape(1,-1).tolist()
scaled_lstm25 = scaled_lstm25.reshape(1,-1).tolist()

# %%
index = test[61:].index

# %%
data = {'Original':scaled_original[0] ,
        'last 10 years model prediction': scaled_lstm10[0] ,
        'last 25 years model prediction':scaled_lstm25[0]}

# %%
df = pd.DataFrame(data=data , index =index)

# %%
df.to_csv('./export.csv')

# %%
print('Mean Absolute Percentage Error : {}'.format(mean_absolute_percentage_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,scaler.inverse_transform(preds) )))
# Out:
# Mean Absolute Percentage Error : 0.01805795691144787

# %%
print('Mean Absolute Percentage Error : {}'.format(mean_absolute_percentage_error(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,scaler.inverse_transform(lstm2_preds) )))
# Out:
# Mean Absolute Percentage Error : 0.016685603036613032

# %%
print('Mean Absolute Percentage Error : {}'.format(mean_absolute_percentage_error(scaler.inverse_transform(np.array(y_train).reshape(-1,1)) ,scaler.inverse_transform(training_predictions) )))
# Out:
# Mean Absolute Percentage Error : 0.011982734133369132

# %%
df.loc['2021-03-03']
# Out:
# Original                          15240.500000
# last 10 years model prediction    14379.541016
# last 25 years model prediction    14749.827148
# Name: 2021-03-03 00:00:00, dtype: float64

# %%
df1 = pd.read_csv('../../data/Equity/NSE50.csv')
df1['Date'] = pd.to_datetime(df1['Date'])
df1.index = df1['Date']
df1.drop(df1[df1['High']==df1['Low']].index , axis=0 , inplace=True)
df1.head()
# Out:
#            Ticker       Date      Time    Open    High    Low   Close  \
# Date
# 1995-11-03  NSE50 1995-11-03  00:00:00   994.0  1001.0  993.0  1000.0
# 1995-11-06  NSE50 1995-11-06  00:00:00  1002.0  1002.0  989.0   989.0
# 1995-11-07  NSE50 1995-11-07  00:00:00   987.0   987.0  977.0   978.0
# 1995-11-08  NSE50 1995-11-08  00:00:00   976.0   976.0  963.0   964.0
# 1995-11-09  NSE50 1995-11-09  00:00:00   960.0   960.0  952.0   953.0
#
#               Volume  OI
# Date
# 1995-11-03  12938015    0
# 1995-11-06   9711115    0
# 1995-11-07  10985070    0
# 1995-11-08   7272730    0
# 1995-11-09   7680380    0

# %%
df1.loc['2021-03-03']
# Out:
# Ticker                  NSE50
# Date      2021-03-03 00:00:00
# Time                 00:00:00
# Open               15064.7998
# High               15273.1504
# Low                14995.7998
# Close                 15240.5
# Volume                    375
# OI                          0
# Name: 2021-03-03 00:00:00, dtype: object

# %%
plt.figure(figsize=(20,10))
plt.scatter(index , scaler.inverse_transform(preds) , label='Testing Prediction')
plt.scatter(index , scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,label='Original')
plt.legend()
plt.show()

# %%
df1.loc['2020-01':]
# Out:
#            Ticker       Date      Time        Open        High         Low  \
# Date
# 2020-03-20  NSE50 2020-03-20  00:00:00   8284.4502   8882.5996   8178.3999
# 2020-03-23  NSE50 2020-03-23  00:00:00   7945.7002   8355.5498   7583.6001
# 2020-03-24  NSE50 2020-03-24  00:00:00   7848.2998   8036.9502   7511.1001
# 2020-03-25  NSE50 2020-03-25  00:00:00   7735.1499   8376.7500   7714.7500
# 2020-03-26  NSE50 2020-03-26  00:00:00   8451.0000   8749.0498   8304.9004
# ...           ...        ...       ...         ...         ...         ...
# 2021-03-15  NSE50 2021-03-15  00:00:00  15038.5498  15044.9004  14745.8496
# 2021-03-16  NSE50 2021-03-16  00:00:00  15005.2002  15051.5996  14890.6504
# 2021-03-17  NSE50 2021-03-17  00:00:00  14955.7002  14956.5498  14696.0498
# 2021-03-18  NSE50 2021-03-18  00:00:00  14837.3496  14875.2002  14478.5996
# 2021-03-19  NSE50 2021-03-19  00:00:00  14478.9004  14788.2500  14350.0996
#
#                  Close  Volume  OI
# Date
# 2020-03-20   8749.7002       0    0
# 2020-03-23   7634.6001       0    0
# 2020-03-24   7856.7998       0    0
# 2020-03-25   8297.7998       0    0
# 2020-03-26   8653.5498       0    0
# ...                ...     ...  ...
# 2021-03-15  14920.9004     358    0
# 2021-03-16  14922.0000     375    0
# 2021-03-17  14709.2500     375    0
# 2021-03-18  14583.7002     375    0
# 2021-03-19  14735.7002     375    0
#
# [212 rows x 9 columns]

# %%
plt.figure(figsize=(40,10))
plt.scatter(df1.index , df1['Close'])
plt.show()

# %%
start = datetime.datetime(1995,  11 , 3)
end = datetime.datetime.now()

# %%
full_data = pdd.DataReader('^NSEI' , 'yahoo' , start=start , end=end)

# %%
full_data.head()
# Out:
#                    High          Low         Open        Close  Volume  \
# Date
# 2007-09-17  4549.049805  4482.850098  4518.450195  4494.649902     0.0
# 2007-09-18  4551.799805  4481.549805  4494.100098  4546.200195     0.0
# 2007-09-19  4739.000000  4550.250000  4550.250000  4732.350098     0.0
# 2007-09-20  4760.850098  4721.149902  4734.850098  4747.549805     0.0
# 2007-09-21  4855.700195  4733.700195  4752.950195  4837.549805     0.0
#
#               Adj Close
# Date
# 2007-09-17  4494.649902
# 2007-09-18  4546.200195
# 2007-09-19  4732.350098
# 2007-09-20  4747.549805
# 2007-09-21  4837.549805

# %%
index[-1]
# Out:
# Timestamp('2021-03-19 00:00:00')

# %%
index[0]
# Out:
# Timestamp('2019-02-12 00:00:00')

# %%
testing_data = full_data.loc['2019-02-12':]

# %%
plt.figure(figsize=(30,10))
plt.scatter(testing_data.index , testing_data['Close'])
plt.show()

# %%
testing_data.loc['2020-01':]
# Out:
#                     High           Low          Open         Close    Volume  \
# Date
# 2020-01-01  12222.200195  12165.299805  12202.150391  12182.500000  304100.0
# 2020-01-02  12289.900391  12195.250000  12198.549805  12282.200195  407700.0
# 2020-01-03  12265.599609  12191.349609  12261.099609  12226.650391  428800.0
# 2020-01-06  12179.099609  11974.200195  12170.599609  11993.049805  396500.0
# 2020-01-07  12152.150391  12005.349609  12079.099609  12052.950195  447800.0
# ...                  ...           ...           ...           ...       ...
# 2021-03-30  14876.299805  14617.599609  14628.500000  14845.099609  594500.0
# 2021-03-31  14813.750000  14670.250000  14811.849609  14690.700195  463900.0
# 2021-04-01  14883.200195  14692.450195  14798.400391  14867.349609  445000.0
# 2021-04-05  14849.849609  14459.500000  14837.700195  14637.799805  509700.0
# 2021-04-06  14779.099609  14573.900391  14737.000000  14669.299805       0.0
#
#                Adj Close
# Date
# 2020-01-01  12182.500000
# 2020-01-02  12282.200195
# 2020-01-03  12226.650391
# 2020-01-06  11993.049805
# 2020-01-07  12052.950195
# ...                  ...
# 2021-03-30  14845.099609
# 2021-03-31  14690.700195
# 2021-04-01  14867.349609
# 2021-04-05  14637.799805
# 2021-04-06  14669.299805
#
# [313 rows x 6 columns]

# %%
plt.figure(figsize=(30,10))
plt.scatter(testing_data.loc['2020-01':].index , testing_data.loc['2020-01':]['Close'])
plt.show()

# %%
testing_data.loc['2020-01':'2020-02']
# Out:
#                     High           Low          Open         Close    Volume  \
# Date
# 2020-01-01  12222.200195  12165.299805  12202.150391  12182.500000  304100.0
# 2020-01-02  12289.900391  12195.250000  12198.549805  12282.200195  407700.0
# 2020-01-03  12265.599609  12191.349609  12261.099609  12226.650391  428800.0
# 2020-01-06  12179.099609  11974.200195  12170.599609  11993.049805  396500.0
# 2020-01-07  12152.150391  12005.349609  12079.099609  12052.950195  447800.0
# 2020-01-08  12044.950195  11929.599609  11939.099609  12025.349609  446000.0
# 2020-01-09  12224.049805  12132.549805  12153.150391  12215.900391  477500.0
# 2020-01-10  12311.200195  12213.200195  12271.000000  12256.799805  660600.0
# 2020-01-13  12337.750000  12285.799805  12296.700195  12329.549805  501000.0
# 2020-01-14  12374.250000  12308.700195  12333.099609  12362.299805  616300.0
# 2020-01-15  12355.150391  12278.750000  12349.400391  12343.299805  684400.0
# 2020-01-16  12389.049805  12315.799805  12347.099609  12355.500000  395700.0
# 2020-01-17  12385.450195  12321.400391  12328.400391  12352.349609  502100.0
# 2020-01-20  12430.500000  12216.900391  12430.500000  12224.549805  491600.0
# 2020-01-21  12230.049805  12162.299805  12195.299805  12169.849609     400.0
# 2020-01-22  12225.049805  12087.900391  12218.349609  12106.900391     500.0
# 2020-01-23  12189.000000  12094.099609  12123.750000  12180.349609  867700.0
# 2020-01-24  12272.150391  12149.650391  12174.549805  12248.250000  593200.0
# 2020-01-27  12216.599609  12107.000000  12197.099609  12119.000000  441200.0
# 2020-01-28  12163.549805  12024.500000  12148.099609  12055.799805  478500.0
# 2020-01-29  12169.599609  12103.799805  12114.900391  12129.500000  514400.0
# 2020-01-30  12150.299805  12010.599609  12147.750000  12035.799805  538100.0
# 2020-01-31  12103.549805  11945.849609  12100.400391  11962.099609  771300.0
# 2020-02-03  11749.849609  11614.500000  11627.450195  11707.900391  669800.0
# 2020-02-04  11986.150391  11783.400391  11786.250000  11979.650391  560400.0
# 2020-02-05  12098.150391  11953.349609  12005.849609  12089.150391  758000.0
# 2020-02-06  12160.599609  12084.650391  12120.000000  12137.950195  565100.0
# 2020-02-07  12154.700195  12073.950195  12151.150391  12098.349609  473500.0
# 2020-02-10  12103.549805  11990.750000  12102.349609  12031.500000  524700.0
# 2020-02-11  12172.299805  12099.000000  12108.400391  12107.900391  480000.0
# 2020-02-12  12231.750000  12144.299805  12151.000000  12201.200195  411700.0
# 2020-02-13  12225.650391  12139.799805  12219.549805  12174.650391  501200.0
# 2020-02-14  12246.700195  12091.200195  12190.150391  12113.450195  622800.0
# 2020-02-17  12159.599609  12037.000000  12131.799805  12045.799805       0.0
# 2020-02-18  12030.750000  11908.049805  12028.250000  11992.500000  676900.0
# 2020-02-19  12134.700195  12042.099609  12090.599609  12125.900391  513600.0
# 2020-02-20  12152.000000  12071.450195  12119.000000  12080.849609  502600.0
# 2020-02-24  12012.549805  11813.400391  12012.549805  11829.400391  490800.0
# 2020-02-25  11883.049805  11779.900391  11877.500000  11797.900391  461000.0
# 2020-02-26  11783.250000  11639.599609  11738.549805  11678.500000  567600.0
# 2020-02-27  11663.849609  11536.700195  11661.250000  11633.299805  608600.0
# 2020-02-28  11384.799805  11175.049805  11382.000000  11201.750000  809900.0
#
#                Adj Close
# Date
# 2020-01-01  12182.500000
# 2020-01-02  12282.200195
# 2020-01-03  12226.650391
# 2020-01-06  11993.049805
# 2020-01-07  12052.950195
# 2020-01-08  12025.349609
# 2020-01-09  12215.900391
# 2020-01-10  12256.799805
# 2020-01-13  12329.549805
# 2020-01-14  12362.299805
# 2020-01-15  12343.299805
# 2020-01-16  12355.500000
# 2020-01-17  12352.349609
# 2020-01-20  12224.549805
# 2020-01-21  12169.849609
# 2020-01-22  12106.900391
# 2020-01-23  12180.349609
# 2020-01-24  12248.250000
# 2020-01-27  12119.000000
# 2020-01-28  12055.799805
# 2020-01-29  12129.500000
# 2020-01-30  12035.799805
# 2020-01-31  11962.099609
# 2020-02-03  11707.900391
# 2020-02-04  11979.650391
# 2020-02-05  12089.150391
# 2020-02-06  12137.950195
# 2020-02-07  12098.349609
# 2020-02-10  12031.500000
# 2020-02-11  12107.900391
# 2020-02-12  12201.200195
# 2020-02-13  12174.650391
# 2020-02-14  12113.450195
# 2020-02-17  12045.799805
# 2020-02-18  11992.500000
# 2020-02-19  12125.900391
# 2020-02-20  12080.849609
# 2020-02-24  11829.400391
# 2020-02-25  11797.900391
# 2020-02-26  11678.500000
# 2020-02-27  11633.299805
# 2020-02-28  11201.750000

# %%
test_scaled_close = scaler.transform(np.array(testing_data['Close']).reshape(-1,1))
test_scaled_open = scaler.transform(np.array(testing_data['Open']).reshape(-1,1))
test_scaled_high = scaler.transform(np.array(testing_data['High']).reshape(-1,1))
test_scaled_low = scaler.transform(np.array(testing_data['Low']).reshape(-1,1))

# %%
open_list = []
close_list = []
high_list = []
low_list = []
for i in range(len(test_scaled_open)):
    open_list.append(test_scaled_open[i])
    high_list.append(test_scaled_high[i])
    low_list.append(test_scaled_low[i])
    close_list.append( test_scaled_close[i])

# %%
open_arr = np.array(open_list).reshape(-1,1)
high_arr = np.array(high_list).reshape(-1,1)
low_arr = np.array(low_list).reshape(-1,1)
close_arr = np.array(close_list).reshape(-1,1)

# %%
scaled_data = pd.DataFrame(open_arr , columns=['Open'])
scaled_data['High'] = high_arr
scaled_data['Low'] = low_arr
scaled_data['Close'] = close_arr

# %%
scaled_test = np.array(scaled_data)

# %%
X_test = []
y_test = []

for x in range(60,len(scaled_test)-1):
    temp = []
    for i in scaled_test[x-60 :x,]:
        temp.append(i[0] )
        temp.append(i[1])
        temp.append( i[2])
        temp.append(i[3])
        
    X_test.append(temp)
    
    y_test.append(scaled_test[x+1][3])

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X_train = X_train.reshape((-1,240 , 1))
y_train = y_train.reshape(-1,1)
X_test = X_test.reshape((-1,240,1))
y_train = y_train.reshape(-1,1)

# %%
preds = lstm.predict(X_test)

# %%
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(preds) , label='Testing Prediction')
plt.plot(scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,label='Original')
plt.legend()
plt.show()

# %%
testing_data.tail()
# Out:
#                     High           Low          Open         Close    Volume  \
# Date
# 2021-03-30  14876.299805  14617.599609  14628.500000  14845.099609  594500.0
# 2021-03-31  14813.750000  14670.250000  14811.849609  14690.700195  463900.0
# 2021-04-01  14883.200195  14692.450195  14798.400391  14867.349609  445000.0
# 2021-04-05  14849.849609  14459.500000  14837.700195  14637.799805  509700.0
# 2021-04-06  14779.099609  14573.900391  14737.000000  14669.299805       0.0
#
#                Adj Close
# Date
# 2021-03-30  14845.099609
# 2021-03-31  14690.700195
# 2021-04-01  14867.349609
# 2021-04-05  14637.799805
# 2021-04-06  14669.299805

# %%
scaler.inverse_transform(preds[-1].reshape(-1,1))
# Out:
# array([[14599.274]], dtype=float32)

# %%
preds.shape
# Out:
# (464, 1)

# %%
testing_data.shape
# Out:
# (525, 6)

# %%
plt.figure(figsize=(20,10))
plt.scatter(testing_data.index , scaler.inverse_transform(preds) , label='Testing Prediction')
plt.scatter(testing_data.index ,scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,label='Original')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-033565533a44> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 plt.scatter(testing_data.index , scaler.inverse_transform(preds) , label='Testing Prediction')
#       3 plt.scatter(testing_data.index ,scaler.inverse_transform(np.array(y_test).reshape(-1,1)) ,label='Original')
#       4 plt.legend()
#       5 plt.show()
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size
